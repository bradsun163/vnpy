# %%
from vnpy.trader.optimize import OptimizationSetting
from vnpy_spreadtrading.backtesting import BacktestingEngine
from vnpy_spreadtrading.strategies.statistical_arbitrage_strategy import (
    StatisticalArbitrageStrategy
)
from vnpy_spreadtrading.base import LegData, SpreadData
from datetime import datetime

# %%
spread = SpreadData(
    name="AP-Spread",
    legs=[LegData("FG307.CZCE"), LegData("FG308.CZCE")],
    variable_symbols={"A": "FG307.CZCE", "B": "FG308.CZCE"},
    variable_directions={"A": 1, "B": -1},
    price_formula="A-B",
    trading_multipliers={"FG307.CZCE": 1, "FG308.CZCE": 1},
    active_symbol="FG307.CZCE",
    min_volume=1,
    compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
)

# %%
engine = BacktestingEngine()
engine.set_parameters(
    spread=spread,
    interval="1m",
    start=datetime(2023, 1, 1), # max at 4,1
    end=datetime(2023, 6, 30),
    rate=0.0006,
    # rate = 0,
    # slippage=0.5,
    slippage=0.5,
    size=20,
    pricetick=1,
    capital=1_000_000,
)
engine.add_strategy(StatisticalArbitrageStrategy, {"boll_window":510, "boll_dev":4})
# Out:
# this utility.py is being used

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2023-12-16 10:40:44.574438	开始加载历史数据
# 2023-12-16 10:40:48.999841	历史数据加载完成，数据量：39885
# 2023-12-16 10:40:49.047045	策略初始化完成
# 2023-12-16 10:40:49.047045	开始回放历史数据
# 2023-12-16 10:40:49.729653	历史数据回放结束
# 2023-12-16 10:40:49.729653	开始计算逐日盯市盈亏
# 2023-12-16 10:40:49.731656	逐日盯市盈亏计算完成
# 2023-12-16 10:40:49.731656	开始计算策略统计指标
# 2023-12-16 10:40:49.735195	------------------------------
# 2023-12-16 10:40:49.735195	首个交易日：	2023-01-17
# 2023-12-16 10:40:49.735195	最后交易日：	2023-06-29
# 2023-12-16 10:40:49.735195	总交易日：	107
# 2023-12-16 10:40:49.735195	盈利交易日：	18
# 2023-12-16 10:40:49.735195	亏损交易日：	9
# 2023-12-16 10:40:49.735195	起始资金：	1,000,000.00
# 2023-12-16 10:40:49.735195	结束资金：	1,021,043.20
# 2023-12-16 10:40:49.735195	总收益率：	2.10%
# 2023-12-16 10:40:49.735195	年化收益：	4.72%
# 2023-12-16 10:40:49.735195	最大回撤: 	-4,141.00
# 2023-12-16 10:40:49.735195	百分比最大回撤: -0.41%
# 2023-12-16 10:40:49.735195	最长回撤天数: 	35
# 2023-12-16 10:40:49.735195	总盈亏：	21,043.20
# 2023-12-16 10:40:49.735195	总手续费：	12,556.80
# 2023-12-16 10:40:49.735195	总滑点：	3,200.00
# 2023-12-16 10:40:49.735195	总成交金额：	20,928,000.00
# 2023-12-16 10:40:49.735195	总成交笔数：	32
# 2023-12-16 10:40:49.735195	日均盈亏：	196.67
# 2023-12-16 10:40:49.735195	日均手续费：	117.35
# 2023-12-16 10:40:49.735195	日均滑点：	29.91
# 2023-12-16 10:40:49.735195	日均成交金额：	195,588.79
# 2023-12-16 10:40:49.735195	日均成交笔数：	0.29906542056074764
# 2023-12-16 10:40:49.735195	日均收益率：	0.02%
# 2023-12-16 10:40:49.735195	收益标准差：	0.09%
# 2023-12-16 10:40:49.735195	Sharpe Ratio：	3.21
# 2023-12-16 10:40:49.735195	收益回撤比：	5.12

# %%
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2023-12-16 09:58:19.367236	开始加载历史数据
# 2023-12-16 09:58:21.662067	历史数据加载完成，数据量：19650
# 2023-12-16 09:58:21.713097	策略初始化完成
# 2023-12-16 09:58:21.713097	开始回放历史数据
# 2023-12-16 09:58:22.026927	历史数据回放结束
# 2023-12-16 09:58:22.026927	开始计算逐日盯市盈亏
# 2023-12-16 09:58:22.028927	逐日盯市盈亏计算完成
# 2023-12-16 09:58:22.028927	开始计算策略统计指标
# 2023-12-16 09:58:22.033444	------------------------------
# 2023-12-16 09:58:22.033444	首个交易日：	2023-04-18
# 2023-12-16 09:58:22.033444	最后交易日：	2023-06-29
# 2023-12-16 09:58:22.033444	总交易日：	48
# 2023-12-16 09:58:22.033444	盈利交易日：	13
# 2023-12-16 09:58:22.033444	亏损交易日：	4
# 2023-12-16 09:58:22.033444	起始资金：	1,000,000.00
# 2023-12-16 09:58:22.033444	结束资金：	1,011,463.04
# 2023-12-16 09:58:22.033444	总收益率：	1.15%
# 2023-12-16 09:58:22.033444	年化收益：	5.73%
# 2023-12-16 09:58:22.033444	最大回撤: 	-3,245.40
# 2023-12-16 09:58:22.033444	百分比最大回撤: -0.32%
# 2023-12-16 09:58:22.033444	最长回撤天数: 	7
# 2023-12-16 09:58:22.033444	总盈亏：	11,463.04
# 2023-12-16 09:58:22.033444	总手续费：	9,336.96
# 2023-12-16 09:58:22.033444	总滑点：	2,400.00
# 2023-12-16 09:58:22.033444	总成交金额：	15,561,600.00
# 2023-12-16 09:58:22.033444	总成交笔数：	24
# 2023-12-16 09:58:22.033444	日均盈亏：	238.81
# 2023-12-16 09:58:22.033444	日均手续费：	194.52
# 2023-12-16 09:58:22.033444	日均滑点：	50.00
# 2023-12-16 09:58:22.033444	日均成交金额：	324,200.00
# 2023-12-16 09:58:22.033444	日均成交笔数：	0.5
# 2023-12-16 09:58:22.033444	日均收益率：	0.02%
# 2023-12-16 09:58:22.033444	收益标准差：	0.13%
# 2023-12-16 09:58:22.033444	Sharpe Ratio：	2.78
# 2023-12-16 09:58:22.033444	收益回撤比：	3.55

# %%
for trade in engine.trades.values():
    print(trade)
# Out:
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1', tradeid='1', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=16.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 17, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='2', tradeid='2', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=19.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='3', tradeid='3', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=20.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 49, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='4', tradeid='4', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=20.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 50, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='5', tradeid='5', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 51, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='6', tradeid='6', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=23.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='7', tradeid='7', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=24.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 55, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='8', tradeid='8', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=18.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 9, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='9', tradeid='9', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=18.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 10, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='10', tradeid='10', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=23.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 10, 7, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='11', tradeid='11', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=27.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 10, 37, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='12', tradeid='12', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=26.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 10, 47, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='13', tradeid='13', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=34.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 10, 51, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='14', tradeid='14', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=32.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 11, 7, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='15', tradeid='15', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=28.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 11, 16, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='16', tradeid='16', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 13, 34, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='17', tradeid='17', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 13, 40, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='18', tradeid='18', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=32.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 13, 44, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='19', tradeid='19', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=29.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 13, 58, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='20', tradeid='20', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 14, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='21', tradeid='21', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=26.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 14, 13, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='22', tradeid='22', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 14, 19, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='23', tradeid='23', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 14, 35, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='24', tradeid='24', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=32.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 14, 51, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='25', tradeid='25', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=43.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 21, 4, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='26', tradeid='26', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=38.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 21, 25, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='27', tradeid='27', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 21, 48, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='28', tradeid='28', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=42.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 21, 52, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='29', tradeid='29', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=39.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 1, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='30', tradeid='30', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=45.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='31', tradeid='31', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=38.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 9, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='32', tradeid='32', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=42.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 13, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='33', tradeid='33', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 32, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='34', tradeid='34', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=43.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 36, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='35', tradeid='35', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=45.0, volume=10, datetime=datetime.datetime(2023, 4, 18, 22, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='36', tradeid='36', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 9, 3, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='37', tradeid='37', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=42.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 9, 8, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='38', tradeid='38', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=44.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 9, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='39', tradeid='39', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=36.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 9, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='40', tradeid='40', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 10, 9, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='41', tradeid='41', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 10, 33, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='42', tradeid='42', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 10, 35, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='43', tradeid='43', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 10, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='44', tradeid='44', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=36.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 11, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='45', tradeid='45', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=36.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 11, 20, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='46', tradeid='46', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=34.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 13, 48, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='47', tradeid='47', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=32.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 14, 11, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='48', tradeid='48', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=33.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 14, 25, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='49', tradeid='49', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 14, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='50', tradeid='50', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 14, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='51', tradeid='51', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 10, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='52', tradeid='52', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 12, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='53', tradeid='53', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=31.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 22, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='54', tradeid='54', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='55', tradeid='55', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 57, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='56', tradeid='56', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=29.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 58, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='57', tradeid='57', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 21, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='58', tradeid='58', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=25.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 1, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='59', tradeid='59', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=28.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='60', tradeid='60', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=29.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 7, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='61', tradeid='61', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=25.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 35, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='62', tradeid='62', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=27.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 43, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='63', tradeid='63', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=26.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 45, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='64', tradeid='64', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=26.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 22, 51, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='65', tradeid='65', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=32.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 9, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='66', tradeid='66', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=38.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 9, 29, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='67', tradeid='67', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 9, 48, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='68', tradeid='68', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=41.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 9, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='69', tradeid='69', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 10, 38, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='70', tradeid='70', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=41.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 10, 48, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='71', tradeid='71', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 10, 52, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='72', tradeid='72', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=39.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 11, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='73', tradeid='73', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=41.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 11, 13, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='74', tradeid='74', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=41.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 11, 28, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='75', tradeid='75', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 13, 34, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='76', tradeid='76', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=39.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 13, 47, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='77', tradeid='77', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=43.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 13, 50, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='78', tradeid='78', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=42.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 13, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='79', tradeid='79', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=38.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 14, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='80', tradeid='80', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 14, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='81', tradeid='81', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=36.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 14, 34, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='82', tradeid='82', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 14, 42, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='83', tradeid='83', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=29.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 21, 7, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='84', tradeid='84', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=24.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 21, 31, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='85', tradeid='85', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=28.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 21, 51, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='86', tradeid='86', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=24.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 21, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='87', tradeid='87', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 22, 11, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='88', tradeid='88', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=24.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 22, 20, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='89', tradeid='89', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=22.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 22, 43, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='90', tradeid='90', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=20.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 22, 56, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='91', tradeid='91', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=16.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 9, 3, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='92', tradeid='92', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=24.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 9, 17, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='93', tradeid='93', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=25.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 9, 18, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='94', tradeid='94', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=17.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 9, 25, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='95', tradeid='95', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=20.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 10, 9, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='96', tradeid='96', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 10, 10, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='97', tradeid='97', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 10, 15, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='98', tradeid='98', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 10, 36, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='99', tradeid='99', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=25.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 10, 38, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='100', tradeid='100', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 10, 42, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='101', tradeid='101', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=22.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 11, 9, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='102', tradeid='102', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=22.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 11, 24, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='103', tradeid='103', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=19.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 11, 30, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='104', tradeid='104', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=11.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 13, 42, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='105', tradeid='105', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=11.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 14, 19, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='106', tradeid='106', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=9.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 14, 33, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='107', tradeid='107', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=11.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 14, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='108', tradeid='108', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 21, 29, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='109', tradeid='109', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=22.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 21, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='110', tradeid='110', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=21.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 22, 4, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='111', tradeid='111', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=18.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 22, 12, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='112', tradeid='112', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=13.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 22, 39, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='113', tradeid='113', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=11.0, volume=10, datetime=datetime.datetime(2023, 4, 21, 22, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='114', tradeid='114', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=15.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 4, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='115', tradeid='115', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=19.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 13, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='116', tradeid='116', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=13.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 17, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='117', tradeid='117', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=14.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 24, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='118', tradeid='118', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=16.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 28, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='119', tradeid='119', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=16.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 31, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='120', tradeid='120', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=18.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 9, 40, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='121', tradeid='121', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=18.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 10, 9, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='122', tradeid='122', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=15.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 10, 13, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='123', tradeid='123', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=15.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 10, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='124', tradeid='124', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=22.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 11, 27, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='125', tradeid='125', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=22.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 11, 29, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='126', tradeid='126', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=23.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 11, 30, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='127', tradeid='127', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=24.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 13, 34, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='128', tradeid='128', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=25.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 13, 41, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='129', tradeid='129', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=28.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 13, 46, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='130', tradeid='130', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=28.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 13, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='131', tradeid='131', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=32.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 14, 4, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='132', tradeid='132', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=28.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 14, 13, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='133', tradeid='133', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=33.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 14, 35, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='134', tradeid='134', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=34.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 14, 42, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='135', tradeid='135', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=30.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 14, 53, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='136', tradeid='136', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=35.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 21, 1, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='137', tradeid='137', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=37.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 21, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='138', tradeid='138', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=34.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 21, 12, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='139', tradeid='139', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=48.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 21, 24, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='140', tradeid='140', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 21, 33, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='141', tradeid='141', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=43.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='142', tradeid='142', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=44.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='143', tradeid='143', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 17, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='144', tradeid='144', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=42.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 24, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='145', tradeid='145', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 37, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='146', tradeid='146', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=40.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 41, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='147', tradeid='147', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=42.0, volume=10, datetime=datetime.datetime(2023, 4, 24, 22, 59, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='148', tradeid='148', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=39.0, volume=10, datetime=datetime.datetime(2023, 4, 25, 9, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='149', tradeid='149', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=50.0, volume=10, datetime=datetime.datetime(2023, 4, 25, 9, 15, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='150', tradeid='150', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=46.0, volume=10, datetime=datetime.datetime(2023, 4, 25, 9, 19, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='151', tradeid='151', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=48.0, volume=10, datetime=datetime.datetime(2023, 4, 25, 9, 44, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='152', tradeid='152', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=39.0, volume=10, datetime=datetime.datetime(2023, 4, 25, 9, 50, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='153', tradeid='153', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=35.0, volume=10, datetime=datetime.datetime(2023, 4, 25, 10, 10, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# ...
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1361', tradeid='1361', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=84.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 11, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1362', tradeid='1362', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=83.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 11, 24, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1363', tradeid='1363', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=86.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 11, 27, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1364', tradeid='1364', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=76.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 13, 38, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1365', tradeid='1365', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 13, 39, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1366', tradeid='1366', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=84.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 13, 45, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1367', tradeid='1367', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=78.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1368', tradeid='1368', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=75.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 28, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1369', tradeid='1369', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 36, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1370', tradeid='1370', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 37, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1371', tradeid='1371', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=72.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 46, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1372', tradeid='1372', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=72.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 49, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1373', tradeid='1373', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=69.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 14, 56, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1374', tradeid='1374', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=72.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 21, 1, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1375', tradeid='1375', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=78.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 21, 6, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1376', tradeid='1376', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=76.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 21, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1377', tradeid='1377', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=80.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 21, 43, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1378', tradeid='1378', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=77.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 21, 52, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1379', tradeid='1379', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=77.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 21, 54, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1380', tradeid='1380', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=79.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 22, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1381', tradeid='1381', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=81.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 22, 18, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1382', tradeid='1382', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=77.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 22, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1383', tradeid='1383', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=73.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 22, 32, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1384', tradeid='1384', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=76.0, volume=10, datetime=datetime.datetime(2023, 6, 28, 22, 44, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1385', tradeid='1385', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=75.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 9, 1, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1386', tradeid='1386', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 9, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1387', tradeid='1387', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=68.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 9, 4, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1388', tradeid='1388', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=67.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 9, 16, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1389', tradeid='1389', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=72.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 9, 29, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1390', tradeid='1390', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 9, 46, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1391', tradeid='1391', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=79.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 10, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1392', tradeid='1392', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=79.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 10, 38, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1393', tradeid='1393', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=75.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 10, 44, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1394', tradeid='1394', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=78.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 10, 50, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1395', tradeid='1395', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 10, 54, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1396', tradeid='1396', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=76.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 11, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1397', tradeid='1397', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=80.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 11, 12, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1398', tradeid='1398', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=81.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 11, 25, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1399', tradeid='1399', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=93.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 13, 54, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1400', tradeid='1400', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=80.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 14, 8, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1401', tradeid='1401', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=85.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 14, 58, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1402', tradeid='1402', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=80.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 21, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1404', tradeid='1403', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=74.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 21, 24, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1405', tradeid='1404', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=69.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 21, 36, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1406', tradeid='1405', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=63.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 21, 47, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1407', tradeid='1406', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=70.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 22, 1, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1408', tradeid='1407', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=55.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 22, 38, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1409', tradeid='1408', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=60.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 22, 41, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1410', tradeid='1409', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=64.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 22, 48, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='AP-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1411', tradeid='1410', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=61.0, volume=10, datetime=datetime.datetime(2023, 6, 29, 23, 0, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("boll_window", 10, 1000, 100)
setting.add_parameter("boll_dev", 1, 5, 1)

engine.run_ga_optimization(setting)
# Out:
# 2023-12-16 09:53:48.813705	开始执行遗传算法优化
# 2023-12-16 09:53:48.813705	参数优化空间：50
# 2023-12-16 09:53:48.813705	每代族群总数：100
# 2023-12-16 09:53:48.813705	优良筛选个数：80
# 2023-12-16 09:53:48.813705	迭代次数：30
# 2023-12-16 09:53:48.813705	交叉概率：95%
# 2023-12-16 09:53:48.813705	突变概率：5%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2023-12-16 09:54:41.574303	遗传算法优化完成，耗时52秒
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 410, 'boll_dev': 4}, 目标：2.3799976371979814
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 710, 'boll_dev': 5}, 目标：2.3431749676275566
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 910, 'boll_dev': 5}, 目标：2.020534257651383
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 610, 'boll_dev': 5}, 目标：1.9816325605593867
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 810, 'boll_dev': 5}, 目标：1.7476954558605478
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 610, 'boll_dev': 4}, 目标：1.2705943359457084
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 510, 'boll_dev': 5}, 目标：1.0960748265484024
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 710, 'boll_dev': 4}, 目标：0.9952521499609477
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 310, 'boll_dev': 4}, 目标：0.7954647629759614
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 510, 'boll_dev': 4}, 目标：0.2800529098642502
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 310, 'boll_dev': 5}, 目标：0.09193281135057657
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 410, 'boll_dev': 5}, 目标：0.06832868749556378
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 10, 'boll_dev': 5}, 目标：0
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 10, 'boll_dev': 4}, 目标：0
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：0
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：0
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 710, 'boll_dev': 3}, 目标：-0.14237932837585218
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 110, 'boll_dev': 5}, 目标：-0.29005398393739995
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 610, 'boll_dev': 3}, 目标：-0.49884761105824665
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 910, 'boll_dev': 3}, 目标：-0.6297957247799213
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 410, 'boll_dev': 3}, 目标：-0.7003033570603613
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 910, 'boll_dev': 4}, 目标：-0.9491403366970841
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 510, 'boll_dev': 3}, 目标：-1.0168405765260236
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 810, 'boll_dev': 3}, 目标：-1.19299580133557
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 810, 'boll_dev': 4}, 目标：-1.1942596665984118
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 910, 'boll_dev': 2}, 目标：-1.837901269174733
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 810, 'boll_dev': 2}, 目标：-1.8598508388792423
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 210, 'boll_dev': 5}, 目标：-1.907513956738202
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 210, 'boll_dev': 4}, 目标：-1.9609753312313094
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 210, 'boll_dev': 3}, 目标：-2.676338733481112
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 310, 'boll_dev': 3}, 目标：-2.710775847667906
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 110, 'boll_dev': 4}, 目标：-3.159923714077136
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 510, 'boll_dev': 2}, 目标：-3.2141293814027097
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 710, 'boll_dev': 2}, 目标：-4.1444868247244155
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 610, 'boll_dev': 2}, 目标：-4.766706908025439
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 910, 'boll_dev': 1}, 目标：-6.841161374835698
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 810, 'boll_dev': 1}, 目标：-7.602622535104136
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 510, 'boll_dev': 1}, 目标：-7.813826181128504
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 710, 'boll_dev': 1}, 目标：-8.235579210665888
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 410, 'boll_dev': 2}, 目标：-8.394231182573542
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 610, 'boll_dev': 1}, 目标：-8.99995837089869
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 310, 'boll_dev': 2}, 目标：-9.50955779439599
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 310, 'boll_dev': 1}, 目标：-9.978236281766048
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 410, 'boll_dev': 1}, 目标：-11.594215997433313
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 110, 'boll_dev': 3}, 目标：-13.140646968959084
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 210, 'boll_dev': 2}, 目标：-14.33857590034668
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 210, 'boll_dev': 1}, 目标：-16.189675098047353
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 110, 'boll_dev': 1}, 目标：-22.329166927377283
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 110, 'boll_dev': 2}, 目标：-22.949388789296798
# 2023-12-16 09:54:41.665394	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：-40.203243097767846
# [("{'boll_window': 410, 'boll_dev': 4}",
#   2.3799976371979814,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 12,
#    'loss_days': 3,
#    'capital': 1000000,
#    'end_balance': 1008801.48,
#    'max_drawdown': -4930.160000000033,
#    'max_ddpercent': -0.4905849748390847,
#    'max_drawdown_duration': 32,
#    'total_net_pnl': 8801.48,
#    'daily_net_pnl': 183.36416666666665,
#    'total_commission': 9398.519999999999,
#    'daily_commission': 195.80249999999998,
#    'total_slippage': 2400.0,
#    'daily_slippage': 50.0,
#    'total_turnover': 15664200.0,
#    'daily_turnover': 326337.5,
#    'total_trade_count': 24,
#    'daily_trade_count': 0.5,
#    'total_return': 0.8801480000000028,
#    'annual_return': 4.400740000000014,
#    'daily_return': 0.018256193243974102,
#    'return_std': 0.11883361780526733,
#    'sharpe_ratio': 2.3799976371979814,
#    'return_drawdown_ratio': 1.794078590133539}),
#  ("{'boll_window': 710, 'boll_dev': 5}",
#   2.3431749676275566,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1003180.48,
#    'max_drawdown': -302.2399999999907,
#    'max_ddpercent': -0.030119103595524863,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 3180.48,
#    'daily_net_pnl': 66.26,
#    'total_commission': 1619.5199999999998,
#    'daily_commission': 33.739999999999995,
#    'total_slippage': 400.0,
#    'daily_slippage': 8.333333333333334,
#    'total_turnover': 2699200.0,
#    'daily_turnover': 56233.333333333336,
#    'total_trade_count': 4,
#    'daily_trade_count': 0.08333333333333333,
#    'total_return': 0.318047999999993,
#    'annual_return': 1.590239999999965,
#    'daily_return': 0.006615485358266213,
#    'return_std': 0.04373837203559025,
#    'sharpe_ratio': 2.3431749676275566,
#    'return_drawdown_ratio': 10.559676817448478}),
#  ("{'boll_window': 910, 'boll_dev': 5}",
#   2.020534257651383,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 1,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1001001.28,
#    'max_drawdown': -100.19999999995343,
#    'max_ddpercent': -0.010008975313866625,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 1001.28,
#    'daily_net_pnl': 20.86,
#    'total_commission': 798.72,
#    'daily_commission': 16.64,
#    'total_slippage': 200.0,
#    'daily_slippage': 4.166666666666667,
#    'total_turnover': 1331200.0,
#    'daily_turnover': 27733.333333333332,
#    'total_trade_count': 2,
#    'daily_trade_count': 0.041666666666666664,
#    'total_return': 0.10012800000001043,
#    'annual_return': 0.5006400000000522,
#    'daily_return': 0.0020849563615514665,
#    'return_std': 0.015985873509007886,
#    'sharpe_ratio': 2.020534257651383,
#    'return_drawdown_ratio': 10.00382125643683}),
#  ("{'boll_window': 610, 'boll_dev': 5}",
#   1.9816325605593867,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1002585.16,
#    'max_drawdown': -697.9199999999255,
#    'max_ddpercent': -0.06956361708002945,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 2585.16,
#    'daily_net_pnl': 53.857499999999995,
#    'total_commission': 1614.84,
#    'daily_commission': 33.6425,
#    'total_slippage': 400.0,
#    'daily_slippage': 8.333333333333334,
#    'total_turnover': 2691400.0,
#    'daily_turnover': 56070.833333333336,
#    'total_trade_count': 4,
#    'daily_trade_count': 0.08333333333333333,
#    'total_return': 0.2585159999999975,
#    'annual_return': 1.2925799999999876,
#    'daily_return': 0.005378800461800533,
#    'return_std': 0.04205018634785785,
#    'sharpe_ratio': 1.9816325605593867,
#    'return_drawdown_ratio': 3.7162529904474035}),
#  ("{'boll_window': 810, 'boll_dev': 5}",
#   1.7476954558605478,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 1,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1000401.4,
#    'max_drawdown': -100.19999999995343,
#    'max_ddpercent': -0.010014976487789068,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 401.40000000000003,
#    'daily_net_pnl': 8.3625,
#    'total_commission': 798.5999999999999,
#    'daily_commission': 16.6375,
#    'total_slippage': 200.0,
#    'daily_slippage': 4.166666666666667,
#    'total_turnover': 1331000.0,
#    'daily_turnover': 27729.166666666668,
#    'total_trade_count': 2,
#    'daily_trade_count': 0.041666666666666664,
#    'total_return': 0.04014000000001072,
#    'annual_return': 0.2007000000000536,
#    'daily_return': 0.0008360822095242206,
#    'return_std': 0.0074112053394409785,
#    'sharpe_ratio': 1.7476954558605478,
#    'return_drawdown_ratio': 4.007997427547844}),
#  ("{'boll_window': 610, 'boll_dev': 4}",
#   1.2705943359457084,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 10,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 1003487.36,
#    'max_drawdown': -9487.119999999995,
#    'max_ddpercent': -0.946349344227202,
#    'max_drawdown_duration': 6,
#    'total_net_pnl': 3487.3600000000015,
#    'daily_net_pnl': 72.65333333333336,
#    'total_commission': 7112.639999999999,
#    'daily_commission': 148.17999999999998,
#    'total_slippage': 1800.0,
#    'daily_slippage': 37.5,
#    'total_turnover': 11854400.0,
#    'daily_turnover': 246966.66666666666,
#    'total_trade_count': 18,
#    'daily_trade_count': 0.375,
#    'total_return': 0.34873600000000504,
#    'annual_return': 1.7436800000000252,
#    'daily_return': 0.013374262487239242,
#    'return_std': 0.16306792629397485,
#    'sharpe_ratio': 1.2705943359457084,
#    'return_drawdown_ratio': 0.3685066219227808}),
#  ("{'boll_window': 510, 'boll_dev': 5}",
#   1.0960748265484024,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 3,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1002470.64,
#    'max_drawdown': -3074.640000000014,
#    'max_ddpercent': -0.3065501372548283,
#    'max_drawdown_duration': 6,
#    'total_net_pnl': 2470.6400000000003,
#    'daily_net_pnl': 51.47166666666667,
#    'total_commission': 3129.3599999999997,
#    'daily_commission': 65.195,
#    'total_slippage': 800.0,
#    'daily_slippage': 16.666666666666668,
#    'total_turnover': 5215600.0,
#    'daily_turnover': 108658.33333333333,
#    'total_trade_count': 8,
#    'daily_trade_count': 0.16666666666666666,
#    'total_return': 0.24706400000000794,
#    'annual_return': 1.2353200000000397,
#    'daily_return': 0.005140818722247132,
#    'return_std': 0.07266038710088084,
#    'sharpe_ratio': 1.0960748265484024,
#    'return_drawdown_ratio': 0.8059497288517902}),
#  ("{'boll_window': 710, 'boll_dev': 4}",
#   0.9952521499609477,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 1002275.44,
#    'max_drawdown': -9487.119999999995,
#    'max_ddpercent': -0.9463495707854735,
#    'max_drawdown_duration': 6,
#    'total_net_pnl': 2275.4400000000005,
#    'daily_net_pnl': 47.40500000000001,
#    'total_commission': 5524.5599999999995,
#    'daily_commission': 115.09499999999998,
#    'total_slippage': 1400.0,
#    'daily_slippage': 29.166666666666668,
#    'total_turnover': 9207600.0,
#    'daily_turnover': 191825.0,
#    'total_trade_count': 14,
#    'daily_trade_count': 0.2916666666666667,
#    'total_return': 0.22754400000000174,
#    'annual_return': 1.1377200000000087,
#    'daily_return': 0.010438581440659572,
#    'return_std': 0.16248526397773952,
#    'sharpe_ratio': 0.9952521499609477,
#    'return_drawdown_ratio': 0.24044391948224736}),
#  ("{'boll_window': 310, 'boll_dev': 4}",
#   0.7954647629759614,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 11,
#    'loss_days': 7,
#    'capital': 1000000,
#    'end_balance': 1003074.24,
#    'max_drawdown': -4908.119999999995,
#    'max_ddpercent': -0.49030202705561843,
#    'max_drawdown_duration': 48,
#    'total_net_pnl': 3074.2400000000025,
#    'daily_net_pnl': 64.04666666666672,
#    'total_commission': 10925.759999999998,
#    'daily_commission': 227.61999999999998,
#    'total_slippage': 2800.0,
#    'daily_slippage': 58.333333333333336,
#    'total_turnover': 18209600.0,
#    'daily_turnover': 379366.6666666667,
#    'total_trade_count': 28,
#    'daily_trade_count': 0.5833333333333334,
#    'total_return': 0.3074239999999895,
#    'annual_return': 1.5371199999999474,
#    'daily_return': 0.006394842055764424,
#    'return_std': 0.1245416161034948,
#    'sharpe_ratio': 0.7954647629759614,
#    'return_drawdown_ratio': 0.627009441193104}),
#  ("{'boll_window': 510, 'boll_dev': 4}",
#   0.2800529098642502,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 22,
#    'loss_days': 15,
#    'capital': 1000000,
#    'end_balance': 1003545.44,
#    'max_drawdown': -21221.160000000033,
#    'max_ddpercent': -2.1123474912735585,
#    'max_drawdown_duration': 39,
#    'total_net_pnl': 3545.4400000000023,
#    'daily_net_pnl': 73.86333333333339,
#    'total_commission': 9754.560000000001,
#    'daily_commission': 203.22000000000003,
#    'total_slippage': 2500.0,
#    'daily_slippage': 52.083333333333336,
#    'total_turnover': 16257600.0,
#    'daily_turnover': 338700.0,
#    'total_trade_count': 24,
#    'daily_trade_count': 0.5,
#    'total_return': 0.35454399999999,
#    'annual_return': 1.77271999999995,
#    'daily_return': 0.007373270299535753,
#    'return_std': 0.4078736848837592,
#    'sharpe_ratio': 0.2800529098642502,
#    'return_drawdown_ratio': 0.16784359650325872}),
#  ("{'boll_window': 310, 'boll_dev': 5}",
#   0.09193281135057657,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 16,
#    'loss_days': 10,
#    'capital': 1000000,
#    'end_balance': 1000758.8,
#    'max_drawdown': -14166.55999999994,
#    'max_ddpercent': -1.4122422346096344,
#    'max_drawdown_duration': 28,
#    'total_net_pnl': 758.8000000000006,
#    'daily_net_pnl': 15.808333333333346,
#    'total_commission': 1141.1999999999998,
#    'daily_commission': 23.774999999999995,
#    'total_slippage': 300.0,
#    'daily_slippage': 6.25,
#    'total_turnover': 1902000.0,
#    'daily_turnover': 39625.0,
#    'total_trade_count': 3,
#    'daily_trade_count': 0.0625,
#    'total_return': 0.07588000000000594,
#    'annual_return': 0.3794000000000297,
#    'daily_return': 0.0015802338683972776,
#    'return_std': 0.2662909733969403,
#    'sharpe_ratio': 0.09193281135057657,
#    'return_drawdown_ratio': 0.053730159133061436}),
#  ("{'boll_window': 410, 'boll_dev': 5}",
#   0.06832868749556378,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 16,
#    'loss_days': 10,
#    'capital': 1000000,
#    'end_balance': 1000564.64,
#    'max_drawdown': -14360.719999999972,
#    'max_ddpercent': -1.4315977416820538,
#    'max_drawdown_duration': 28,
#    'total_net_pnl': 564.6400000000008,
#    'daily_net_pnl': 11.76333333333335,
#    'total_commission': 1935.36,
#    'daily_commission': 40.32,
#    'total_slippage': 500.0,
#    'daily_slippage': 10.416666666666666,
#    'total_turnover': 3225600.0,
#    'daily_turnover': 67200.0,
#    'total_trade_count': 5,
#    'daily_trade_count': 0.10416666666666667,
#    'total_return': 0.056464000000011616,
#    'annual_return': 0.2823200000000581,
#    'daily_return': 0.0011760013558652048,
#    'return_std': 0.2666308300845959,
#    'sharpe_ratio': 0.06832868749556378,
#    'return_drawdown_ratio': 0.039441246906180026}),
#  ("{'boll_window': 10, 'boll_dev': 5}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 4}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 710, 'boll_dev': 3}",
#   -0.14237932837585218,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 21,
#    'loss_days': 14,
#    'capital': 1000000,
#    'end_balance': 994817.0,
#    'max_drawdown': -16887.0,
#    'max_ddpercent': -1.6842289783848206,
#    'max_drawdown_duration': 40,
#    'total_net_pnl': -5182.999999999999,
#    'daily_net_pnl': -107.97916666666664,
#    'total_commission': 16683.0,
#    'daily_commission': 347.5625,
#    'total_slippage': 4100.0,
#    'daily_slippage': 85.41666666666667,
#    'total_turnover': 27805000.0,
#    'daily_turnover': 579270.8333333334,
#    'total_trade_count': 41,
#    'daily_trade_count': 0.8541666666666666,
#    'total_return': -0.5183000000000049,
#    'annual_return': -2.5915000000000243,
#    'daily_return': -0.002200582353189741,
#    'return_std': 0.23943978112787,
#    'sharpe_ratio': -0.14237932837585218,
#    'return_drawdown_ratio': -0.3077372534565079}),
#  ("{'boll_window': 110, 'boll_dev': 5}",
#   -0.29005398393739995,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 4,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 999237.72,
#    'max_drawdown': -5280.640000000014,
#    'max_ddpercent': -0.5271326199165233,
#    'max_drawdown_duration': 7,
#    'total_net_pnl': -762.28,
#    'daily_net_pnl': -15.880833333333333,
#    'total_commission': 3962.2799999999997,
#    'daily_commission': 82.5475,
#    'total_slippage': 1000.0,
#    'daily_slippage': 20.833333333333332,
#    'total_turnover': 6603800.0,
#    'daily_turnover': 137579.16666666666,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.20833333333333334,
#    'total_return': -0.0762280000000004,
#    'annual_return': -0.38114000000000203,
#    'daily_return': -0.0015886889231876461,
#    'return_std': 0.08485269753285503,
#    'sharpe_ratio': -0.29005398393739995,
#    'return_drawdown_ratio': -0.14460877039268008}),
#  ("{'boll_window': 610, 'boll_dev': 3}",
#   -0.49884761105824665,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 18,
#    'loss_days': 18,
#    'capital': 1000000,
#    'end_balance': 992225.16,
#    'max_drawdown': -16899.560000000056,
#    'max_ddpercent': -1.6861204805756111,
#    'max_drawdown_duration': 40,
#    'total_net_pnl': -7774.839999999999,
#    'daily_net_pnl': -161.97583333333333,
#    'total_commission': 19674.839999999997,
#    'daily_commission': 409.8924999999999,
#    'total_slippage': 4900.0,
#    'daily_slippage': 102.08333333333333,
#    'total_turnover': 32791400.0,
#    'daily_turnover': 683154.1666666666,
#    'total_trade_count': 49,
#    'daily_trade_count': 1.0208333333333333,
#    'total_return': -0.777483999999995,
#    'annual_return': -3.8874199999999743,
#    'daily_return': -0.007635464247160276,
#    'return_std': 0.23712272216423225,
#    'sharpe_ratio': -0.49884761105824665,
#    'return_drawdown_ratio': -0.461108211991219}),
#  ("{'boll_window': 910, 'boll_dev': 3}",
#   -0.6297957247799213,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 17,
#    'loss_days': 12,
#    'capital': 1000000,
#    'end_balance': 992833.96,
#    'max_drawdown': -14074.359999999986,
#    'max_ddpercent': -1.4074432624072326,
#    'max_drawdown_duration': 63,
#    'total_net_pnl': -7166.04,
#    'daily_net_pnl': -149.2925,
#    'total_commission': 11366.039999999997,
#    'daily_commission': 236.79249999999993,
#    'total_slippage': 2800.0,
#    'daily_slippage': 58.333333333333336,
#    'total_turnover': 18943400.0,
#    'daily_turnover': 394654.1666666667,
#    'total_trade_count': 28,
#    'daily_trade_count': 0.5833333333333334,
#    'total_return': -0.7166039999999985,
#    'annual_return': -3.5830199999999923,
#    'daily_return': -0.009279532097564993,
#    'return_std': 0.22826114475150017,
#    'sharpe_ratio': -0.6297957247799213,
#    'return_drawdown_ratio': -0.5091530288576953}),
#  ("{'boll_window': 410, 'boll_dev': 3}",
#   -0.7003033570603613,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 28,
#    'loss_days': 20,
#    'capital': 1000000,
#    'end_balance': 981858.04,
#    'max_drawdown': -34904.4800000001,
#    'max_ddpercent': -3.4911997251248237,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': -18141.960000000003,
#    'daily_net_pnl': -377.95750000000004,
#    'total_commission': 25041.96,
#    'daily_commission': 521.7075,
#    'total_slippage': 6300.0,
#    'daily_slippage': 131.25,
#    'total_turnover': 41736600.0,
#    'daily_turnover': 869512.5,
#    'total_trade_count': 63,
#    'daily_trade_count': 1.3125,
#    'total_return': -1.8141960000000013,
#    'annual_return': -9.070980000000006,
#    'daily_return': -0.02169168221033571,
#    'return_std': 0.4798578964665034,
#    'sharpe_ratio': -0.7003033570603613,
#    'return_drawdown_ratio': -0.5196482993923062}),
#  ("{'boll_window': 910, 'boll_dev': 4}",
#   -0.9491403366970841,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 993552.52,
#    'max_drawdown': -13360.959999999963,
#    'max_ddpercent': -1.3360959999999964,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -6447.48,
#    'daily_net_pnl': -134.3225,
#    'total_commission': 4647.48,
#    'daily_commission': 96.82249999999999,
#    'total_slippage': 1200.0,
#    'daily_slippage': 25.0,
#    'total_turnover': 7745800.0,
#    'daily_turnover': 161370.83333333334,
#    'total_trade_count': 12,
#    'daily_trade_count': 0.25,
#    'total_return': -0.644747999999995,
#    'annual_return': -3.223739999999975,
#    'daily_return': -0.01347573911251908,
#    'return_std': 0.21995193394579773,
#    'sharpe_ratio': -0.9491403366970841,
#    'return_drawdown_ratio': -0.48256113333173417}),
#  ("{'boll_window': 510, 'boll_dev': 3}",
#   -1.0168405765260236,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 17,
#    'loss_days': 21,
#    'capital': 1000000,
#    'end_balance': 989781.12,
#    'max_drawdown': -14626.520000000019,
#    'max_ddpercent': -1.4656977786118686,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -10218.879999999997,
#    'daily_net_pnl': -212.8933333333333,
#    'total_commission': 22718.879999999997,
#    'daily_commission': 473.30999999999995,
#    'total_slippage': 5700.0,
#    'daily_slippage': 118.75,
#    'total_turnover': 37864800.0,
#    'daily_turnover': 788850.0,
#    'total_trade_count': 57,
#    'daily_trade_count': 1.1875,
#    'total_return': -1.0218880000000041,
#    'annual_return': -5.109440000000021,
#    'daily_return': -0.012773442498966297,
#    'return_std': 0.19460800921713972,
#    'sharpe_ratio': -1.0168405765260236,
#    'return_drawdown_ratio': -0.6972023939122106}),
#  ("{'boll_window': 810, 'boll_dev': 3}",
#   -1.19299580133557,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 15,
#    'loss_days': 15,
#    'capital': 1000000,
#    'end_balance': 988931.48,
#    'max_drawdown': -17484.31999999995,
#    'max_ddpercent': -1.7484406023277586,
#    'max_drawdown_duration': 63,
#    'total_net_pnl': -11068.519999999997,
#    'daily_net_pnl': -230.5941666666666,
#    'total_commission': 11768.52,
#    'daily_commission': 245.1775,
#    'total_slippage': 2900.0,
#    'daily_slippage': 60.416666666666664,
#    'total_turnover': 19614200.0,
#    'daily_turnover': 408629.1666666667,
#    'total_trade_count': 29,
#    'daily_trade_count': 0.6041666666666666,
#    'total_return': -1.1068520000000026,
#    'annual_return': -5.534260000000013,
#    'daily_return': -0.01748451641249715,
#    'return_std': 0.22704938544220063,
#    'sharpe_ratio': -1.19299580133557,
#    'return_drawdown_ratio': -0.6330509589667574}),
#  ("{'boll_window': 810, 'boll_dev': 4}",
#   -1.1942596665984118,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 8,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 991981.6,
#    'max_drawdown': -14731.76000000001,
#    'max_ddpercent': -1.473176000000001,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -8018.400000000001,
#    'daily_net_pnl': -167.05,
#    'total_commission': 3818.3999999999996,
#    'daily_commission': 79.55,
#    'total_slippage': 1000.0,
#    'daily_slippage': 20.833333333333332,
#    'total_turnover': 6364000.0,
#    'daily_turnover': 132583.33333333334,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.20833333333333334,
#    'total_return': -0.8018399999999981,
#    'annual_return': -4.00919999999999,
#    'daily_return': -0.016772333867468354,
#    'return_std': 0.21757067265197705,
#    'sharpe_ratio': -1.1942596665984118,
#    'return_drawdown_ratio': -0.5442934177586368}),
#  ("{'boll_window': 910, 'boll_dev': 2}",
#   -1.837901269174733,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 23,
#    'loss_days': 21,
#    'capital': 1000000,
#    'end_balance': 961045.36,
#    'max_drawdown': -56523.07999999996,
#    'max_ddpercent': -5.654870334846121,
#    'max_drawdown_duration': 61,
#    'total_net_pnl': -38954.64,
#    'daily_net_pnl': -811.555,
#    'total_commission': 35954.64,
#    'daily_commission': 749.055,
#    'total_slippage': 9000.0,
#    'daily_slippage': 187.5,
#    'total_turnover': 59924400.0,
#    'daily_turnover': 1248425.0,
#    'total_trade_count': 90,
#    'daily_trade_count': 1.875,
#    'total_return': -3.895464000000004,
#    'annual_return': -19.47732000000002,
#    'daily_return': -0.06633391518361083,
#    'return_std': 0.5591380845179341,
#    'sharpe_ratio': -1.837901269174733,
#    'return_drawdown_ratio': -0.688868845673719}),
#  ("{'boll_window': 810, 'boll_dev': 2}",
#   -1.8598508388792423,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 24,
#    'loss_days': 21,
#    'capital': 1000000,
#    'end_balance': 960526.88,
#    'max_drawdown': -56942.95999999996,
#    'max_ddpercent': -5.688345308206175,
#    'max_drawdown_duration': 39,
#    'total_net_pnl': -39473.119999999995,
#    'daily_net_pnl': -822.3566666666666,
#    'total_commission': 39273.119999999995,
#    'daily_commission': 818.1899999999999,
#    'total_slippage': 9800.0,
#    'daily_slippage': 204.16666666666666,
#    'total_turnover': 65455200.0,
#    'daily_turnover': 1363650.0,
#    'total_trade_count': 98,
#    'daily_trade_count': 2.0416666666666665,
#    'total_return': -3.947312000000003,
#    'annual_return': -19.73656000000001,
#    'daily_return': -0.06745816819933846,
#    'return_std': 0.5619039044209291,
#    'sharpe_ratio': -1.8598508388792423,
#    'return_drawdown_ratio': -0.693929743383457}),
#  ("{'boll_window': 210, 'boll_dev': 5}",
#   -1.907513956738202,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 3,
#    'loss_days': 4,
#    'capital': 1000000,
#    'end_balance': 993983.04,
#    'max_drawdown': -9911.79999999993,
#    'max_ddpercent': -0.9896170779564349,
#    'max_drawdown_duration': 40,
#    'total_net_pnl': -6016.96,
#    'daily_net_pnl': -125.35333333333334,
#    'total_commission': 3816.96,
#    'daily_commission': 79.52,
#    'total_slippage': 1000.0,
#    'daily_slippage': 20.833333333333332,
#    'total_turnover': 6361600.0,
#    'daily_turnover': 132533.33333333334,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.20833333333333334,
#    'total_return': -0.601695999999996,
#    'annual_return': -3.00847999999998,
#    'daily_return': -0.012573197594525479,
#    'return_std': 0.10211361174088777,
#    'sharpe_ratio': -1.907513956738202,
#    'return_drawdown_ratio': -0.6080089091050266}),
#  ("{'boll_window': 210, 'boll_dev': 4}",
#   -1.9609753312313094,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 8,
#    'loss_days': 8,
#    'capital': 1000000,
#    'end_balance': 992914.88,
#    'max_drawdown': -13195.560000000056,
#    'max_ddpercent': -1.3145673221777268,
#    'max_drawdown_duration': 48,
#    'total_net_pnl': -7085.12,
#    'daily_net_pnl': -147.60666666666665,
#    'total_commission': 11085.12,
#    'daily_commission': 230.94000000000003,
#    'total_slippage': 2800.0,
#    'daily_slippage': 58.333333333333336,
#    'total_turnover': 18475200.0,
#    'daily_turnover': 384900.0,
#    'total_trade_count': 28,
#    'daily_trade_count': 0.5833333333333334,
#    'total_return': -0.7085119999999945,
#    'annual_return': -3.5425599999999724,
#    'daily_return': -0.014813205523789367,
#    'return_std': 0.11702604797493321,
#    'sharpe_ratio': -1.9609753312313094,
#    'return_drawdown_ratio': -0.5389697340310161}),
#  ("{'boll_window': 210, 'boll_dev': 3}",
#   -2.676338733481112,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 20,
#    'loss_days': 28,
#    'capital': 1000000,
#    'end_balance': 956447.48,
#    'max_drawdown': -57087.20000000007,
#    'max_ddpercent': -5.718128837915066,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': -43552.52,
#    'daily_net_pnl': -907.3441666666666,
#    'total_commission': 43652.52,
#    'daily_commission': 909.4274999999999,
#    'total_slippage': 10700.0,
#    'daily_slippage': 222.91666666666666,
#    'total_turnover': 72754200.0,
#    'daily_turnover': 1515712.5,
#    'total_trade_count': 107,
#    'daily_trade_count': 2.2291666666666665,
#    'total_return': -4.355251999999998,
#    'annual_return': -21.776259999999994,
#    'daily_return': -0.07841700779781176,
#    'return_std': 0.4539152857759669,
#    'sharpe_ratio': -2.676338733481112,
#    'return_drawdown_ratio': -0.7616568502482365}),
#  ("{'boll_window': 310, 'boll_dev': 3}",
#   -2.710775847667906,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 17,
#    'loss_days': 23,
#    'capital': 1000000,
#    'end_balance': 981776.92,
#    'max_drawdown': -24889.76000000001,
#    'max_ddpercent': -2.4857731310361233,
#    'max_drawdown_duration': 61,
#    'total_net_pnl': -18223.079999999998,
#    'daily_net_pnl': -379.6475,
#    'total_commission': 31423.079999999998,
#    'daily_commission': 654.6474999999999,
#    'total_slippage': 7800.0,
#    'daily_slippage': 162.5,
#    'total_turnover': 52371800.0,
#    'daily_turnover': 1091079.1666666667,
#    'total_trade_count': 78,
#    'daily_trade_count': 1.625,
#    'total_return': -1.8223079999999947,
#    'annual_return': -9.111539999999973,
#    'daily_return': -0.029689513895728922,
#    'return_std': 0.16967392265070635,
#    'sharpe_ratio': -2.710775847667906,
#    'return_drawdown_ratio': -0.7330950589366206}),
#  ("{'boll_window': 110, 'boll_dev': 4}",
#   -3.159923714077136,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 12,
#    'loss_days': 15,
#    'capital': 1000000,
#    'end_balance': 987112.6,
#    'max_drawdown': -17014.280000000028,
#    'max_ddpercent': -1.700909562765272,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': -12887.399999999998,
#    'daily_net_pnl': -268.48749999999995,
#    'total_commission': 23687.399999999994,
#    'daily_commission': 493.4874999999999,
#    'total_slippage': 5800.0,
#    'daily_slippage': 120.83333333333333,
#    'total_turnover': 39479000.0,
#    'daily_turnover': 822479.1666666666,
#    'total_trade_count': 58,
#    'daily_trade_count': 1.2083333333333333,
#    'total_return': -1.2887399999999993,
#    'annual_return': -6.443699999999997,
#    'daily_return': -0.026818162770958085,
#    'return_std': 0.13147950037538783,
#    'sharpe_ratio': -3.159923714077136,
#    'return_drawdown_ratio': -0.7576769677894082}),
#  ("{'boll_window': 510, 'boll_dev': 2}",
#   -3.2141293814027097,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 21,
#    'loss_days': 27,
#    'capital': 1000000,
#    'end_balance': 936748.28,
#    'max_drawdown': -77142.92000000004,
#    'max_ddpercent': -7.729987275363392,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': -63251.72,
#    'daily_net_pnl': -1317.7441666666666,
#    'total_commission': 56451.719999999994,
#    'daily_commission': 1176.0774999999999,
#    'total_slippage': 14200.0,
#    'daily_slippage': 295.8333333333333,
#    'total_turnover': 94086200.0,
#    'daily_turnover': 1960129.1666666667,
#    'total_trade_count': 142,
#    'daily_trade_count': 2.9583333333333335,
#    'total_return': -6.325172000000001,
#    'annual_return': -31.625860000000007,
#    'daily_return': -0.11673166333966564,
#    'return_std': 0.5626404347074674,
#    'sharpe_ratio': -3.2141293814027097,
#    'return_drawdown_ratio': -0.8182642189023074}),
#  ("{'boll_window': 710, 'boll_dev': 2}",
#   -4.1444868247244155,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 19,
#    'loss_days': 25,
#    'capital': 1000000,
#    'end_balance': 960022.76,
#    'max_drawdown': -41946.04000000004,
#    'max_ddpercent': -4.204211126930375,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -39977.23999999999,
#    'daily_net_pnl': -832.8591666666665,
#    'total_commission': 41877.23999999999,
#    'daily_commission': 872.4424999999998,
#    'total_slippage': 10500.0,
#    'daily_slippage': 218.75,
#    'total_turnover': 69795400.0,
#    'daily_turnover': 1454070.8333333333,
#    'total_trade_count': 105,
#    'daily_trade_count': 2.1875,
#    'total_return': -3.9977240000000025,
#    'annual_return': -19.988620000000015,
#    'daily_return': -0.07511067912555686,
#    'return_std': 0.2807608484989734,
#    'sharpe_ratio': -4.1444868247244155,
#    'return_drawdown_ratio': -0.9508856428242378}),
#  ("{'boll_window': 610, 'boll_dev': 2}",
#   -4.766706908025439,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 16,
#    'loss_days': 29,
#    'capital': 1000000,
#    'end_balance': 954241.36,
#    'max_drawdown': -49359.80000000005,
#    'max_ddpercent': -4.947288710425844,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -45758.64,
#    'daily_net_pnl': -953.305,
#    'total_commission': 46658.64,
#    'daily_commission': 972.055,
#    'total_slippage': 11700.0,
#    'daily_slippage': 243.75,
#    'total_turnover': 77764400.0,
#    'daily_turnover': 1620091.6666666667,
#    'total_trade_count': 117,
#    'daily_trade_count': 2.4375,
#    'total_return': -4.575863999999996,
#    'annual_return': -22.87931999999998,
#    'daily_return': -0.08769475237743025,
#    'return_std': 0.2850104460467139,
#    'sharpe_ratio': -4.766706908025439,
#    'return_drawdown_ratio': -0.9249235829631061}),
#  ("{'boll_window': 910, 'boll_dev': 1}",
#   -6.841161374835698,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 13,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 904404.0,
#    'max_drawdown': -102974.88,
#    'max_ddpercent': -10.323794680653455,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -95595.99999999999,
#    'daily_net_pnl': -1991.583333333333,
#    'total_commission': 106896.0,
#    'daily_commission': 2227.0,
#    'total_slippage': 26900.0,
#    'daily_slippage': 560.4166666666666,
#    'total_turnover': 178160000.0,
#    'daily_turnover': 3711666.6666666665,
#    'total_trade_count': 269,
#    'daily_trade_count': 5.604166666666667,
#    'total_return': -9.559600000000001,
#    'annual_return': -47.798,
#    'daily_return': -0.19888601564543693,
#    'return_std': 0.4503809714074021,
#    'sharpe_ratio': -6.841161374835698,
#    'return_drawdown_ratio': -0.9259773460929501}),
#  ("{'boll_window': 810, 'boll_dev': 1}",
#   -7.602622535104136,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 14,
#    'loss_days': 34,
#    'capital': 1000000,
#    'end_balance': 894918.24,
#    'max_drawdown': -110621.80000000005,
#    'max_ddpercent': -11.095624431160408,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -105081.76,
#    'daily_net_pnl': -2189.2033333333334,
#    'total_commission': 116381.76,
#    'daily_commission': 2424.62,
#    'total_slippage': 29300.0,
#    'daily_slippage': 610.4166666666666,
#    'total_turnover': 193969600.0,
#    'daily_turnover': 4041033.3333333335,
#    'total_trade_count': 293,
#    'daily_trade_count': 6.104166666666667,
#    'total_return': -10.508176000000002,
#    'annual_return': -52.540880000000016,
#    'daily_return': -0.21987624237803619,
#    'return_std': 0.44804382752122796,
#    'sharpe_ratio': -7.602622535104136,
#    'return_drawdown_ratio': -0.9470558475726122}),
#  ("{'boll_window': 510, 'boll_dev': 1}",
#   -7.813826181128504,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 15,
#    'loss_days': 33,
#    'capital': 1000000,
#    'end_balance': 832681.04,
#    'max_drawdown': -171355.80000000005,
#    'max_ddpercent': -17.30276694746386,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': -167318.96,
#    'daily_net_pnl': -3485.8116666666665,
#    'total_commission': 165318.96,
#    'daily_commission': 3444.145,
#    'total_slippage': 41600.0,
#    'daily_slippage': 866.6666666666666,
#    'total_turnover': 275531600.0,
#    'daily_turnover': 5740241.666666667,
#    'total_trade_count': 415,
#    'daily_trade_count': 8.645833333333334,
#    'total_return': -16.731896000000003,
#    'annual_return': -83.65948000000002,
#    'daily_return': -0.35729786623147375,
#    'return_std': 0.7083897969944799,
#    'sharpe_ratio': -7.813826181128504,
#    'return_drawdown_ratio': -0.9670069562170499}),
#  ("{'boll_window': 710, 'boll_dev': 1}",
#   -8.235579210665888,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 12,
#    'loss_days': 36,
#    'capital': 1000000,
#    'end_balance': 890247.12,
#    'max_drawdown': -117111.08000000007,
#    'max_ddpercent': -11.742025693011762,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -109752.87999999999,
#    'daily_net_pnl': -2286.518333333333,
#    'total_commission': 116252.87999999999,
#    'daily_commission': 2421.935,
#    'total_slippage': 29300.0,
#    'daily_slippage': 610.4166666666666,
#    'total_turnover': 193754800.0,
#    'daily_turnover': 4036558.3333333335,
#    'total_trade_count': 293,
#    'daily_trade_count': 6.104166666666667,
#    'total_return': -10.975288000000006,
#    'annual_return': -54.87644000000003,
#    'daily_return': -0.2318941994624852,
#    'return_std': 0.4362157655831416,
#    'sharpe_ratio': -8.235579210665888,
#    'return_drawdown_ratio': -0.93470141242596}),
#  ("{'boll_window': 410, 'boll_dev': 2}",
#   -8.394231182573542,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 10,
#    'loss_days': 36,
#    'capital': 1000000,
#    'end_balance': 942569.88,
#    'max_drawdown': -57627.95999999996,
#    'max_ddpercent': -5.780662408920495,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -57430.119999999995,
#    'daily_net_pnl': -1196.4608333333333,
#    'total_commission': 65130.119999999995,
#    'daily_commission': 1356.8774999999998,
#    'total_slippage': 16300.0,
#    'daily_slippage': 339.5833333333333,
#    'total_turnover': 108550200.0,
#    'daily_turnover': 2261462.5,
#    'total_trade_count': 163,
#    'daily_trade_count': 3.3958333333333335,
#    'total_return': -5.743012000000003,
#    'annual_return': -28.715060000000012,
#    'daily_return': -0.11571127761979272,
#    'return_std': 0.2135503973825248,
#    'sharpe_ratio': -8.394231182573542,
#    'return_drawdown_ratio': -0.99348683485436}),
#  ("{'boll_window': 610, 'boll_dev': 1}",
#   -8.99995837089869,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 11,
#    'loss_days': 37,
#    'capital': 1000000,
#    'end_balance': 874110.88,
#    'max_drawdown': -128554.23999999999,
#    'max_ddpercent': -12.899675563038468,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -125889.12,
#    'daily_net_pnl': -2622.69,
#    'total_commission': 135189.12,
#    'daily_commission': 2816.44,
#    'total_slippage': 34100.0,
#    'daily_slippage': 710.4166666666666,
#    'total_turnover': 225315200.0,
#    'daily_turnover': 4694066.666666667,
#    'total_trade_count': 341,
#    'daily_trade_count': 7.104166666666667,
#    'total_return': -12.588911999999997,
#    'annual_return': -62.94455999999998,
#    'daily_return': -0.2691640926114772,
#    'return_std': 0.46332127555260527,
#    'sharpe_ratio': -8.99995837089869,
#    'return_drawdown_ratio': -0.975909195427449}),
#  ("{'boll_window': 310, 'boll_dev': 2}",
#   -9.50955779439599,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 13,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 931763.72,
#    'max_drawdown': -70601.95999999996,
#    'max_ddpercent': -7.09139102913717,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -68236.28,
#    'daily_net_pnl': -1421.5891666666666,
#    'total_commission': 82136.28,
#    'daily_commission': 1711.1725,
#    'total_slippage': 20500.0,
#    'daily_slippage': 427.0833333333333,
#    'total_turnover': 136893800.0,
#    'daily_turnover': 2851954.1666666665,
#    'total_trade_count': 205,
#    'daily_trade_count': 4.270833333333333,
#    'total_return': -6.823628000000004,
#    'annual_return': -34.11814000000002,
#    'daily_return': -0.13805689933655146,
#    'return_std': 0.2249072285041869,
#    'sharpe_ratio': -9.50955779439599,
#    'return_drawdown_ratio': -0.9622411134801369}),
#  ("{'boll_window': 310, 'boll_dev': 1}",
#   -9.978236281766048,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 13,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 749551.52,
#    'max_drawdown': -254627.07999999996,
#    'max_ddpercent': -25.7093335229927,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -250448.47999999998,
#    'daily_net_pnl': -5217.676666666666,
#    'total_commission': 256248.47999999998,
#    'daily_commission': 5338.509999999999,
#    'total_slippage': 64600.0,
#    'daily_slippage': 1345.8333333333333,
#    'total_turnover': 427080800.0,
#    'daily_turnover': 8897516.666666666,
#    'total_trade_count': 645,
#    'daily_trade_count': 13.4375,
#    'total_return': -25.044847999999998,
#    'annual_return': -125.22424,
#    'daily_return': -0.5771184803155239,
#    'return_std': 0.8960181739272082,
#    'sharpe_ratio': -9.978236281766048,
#    'return_drawdown_ratio': -0.9741539187548977}),
#  ("{'boll_window': 410, 'boll_dev': 1}",
#   -11.594215997433313,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 7,
#    'loss_days': 41,
#    'capital': 1000000,
#    'end_balance': 812442.8,
#    'max_drawdown': -184822.4800000001,
#    'max_ddpercent': -18.583851864978442,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -187557.19999999998,
#    'daily_net_pnl': -3907.441666666666,
#    'total_commission': 191257.19999999998,
#    'daily_commission': 3984.5249999999996,
#    'total_slippage': 48100.0,
#    'daily_slippage': 1002.0833333333334,
#    'total_turnover': 318762000.0,
#    'daily_turnover': 6640875.0,
#    'total_trade_count': 481,
#    'daily_trade_count': 10.020833333333334,
#    'total_return': -18.755719999999997,
#    'annual_return': -93.77859999999998,
#    'daily_return': -0.42130718075513707,
#    'return_std': 0.5629412786732514,
#    'sharpe_ratio': -11.594215997433313,
#    'return_drawdown_ratio': -1.0092482514534806}),
#  ("{'boll_window': 110, 'boll_dev': 3}",
#   -13.140646968959084,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 5,
#    'loss_days': 40,
#    'capital': 1000000,
#    'end_balance': 938457.52,
#    'max_drawdown': -63653.52000000002,
#    'max_ddpercent': -6.365576068277605,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': -61542.479999999996,
#    'daily_net_pnl': -1282.135,
#    'total_commission': 70542.48,
#    'daily_commission': 1469.635,
#    'total_slippage': 17400.0,
#    'daily_slippage': 362.5,
#    'total_turnover': 117570800.0,
#    'daily_turnover': 2449391.6666666665,
#    'total_trade_count': 174,
#    'daily_trade_count': 3.625,
#    'total_return': -6.1542479999999955,
#    'annual_return': -30.771239999999974,
#    'daily_return': -0.1322551814149413,
#    'return_std': 0.15591990752957066,
#    'sharpe_ratio': -13.140646968959084,
#    'return_drawdown_ratio': -0.9668014228388931}),
#  ("{'boll_window': 210, 'boll_dev': 2}",
#   -14.33857590034668,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 39,
#    'capital': 1000000,
#    'end_balance': 893369.8,
#    'max_drawdown': -103068.64000000001,
#    'max_ddpercent': -10.357980634430918,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': -106630.19999999998,
#    'daily_net_pnl': -2221.4624999999996,
#    'total_commission': 123130.2,
#    'daily_commission': 2565.2125,
#    'total_slippage': 30700.0,
#    'daily_slippage': 639.5833333333334,
#    'total_turnover': 205217000.0,
#    'daily_turnover': 4275354.166666667,
#    'total_trade_count': 307,
#    'daily_trade_count': 6.395833333333333,
#    'total_return': -10.663020000000001,
#    'annual_return': -53.3151,
#    'daily_return': -0.22459886824771394,
#    'return_std': 0.24266501285651337,
#    'sharpe_ratio': -14.33857590034668,
#    'return_drawdown_ratio': -1.02944969452396}),
#  ("{'boll_window': 210, 'boll_dev': 1}",
#   -16.189675098047353,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 46,
#    'capital': 1000000,
#    'end_balance': 629639.44,
#    'max_drawdown': -363083.88,
#    'max_ddpercent': -36.59127809828005,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': -370360.55999999994,
#    'daily_net_pnl': -7715.844999999998,
#    'total_commission': 361660.55999999994,
#    'daily_commission': 7534.594999999998,
#    'total_slippage': 90900.0,
#    'daily_slippage': 1893.75,
#    'total_turnover': 602767600.0,
#    'daily_turnover': 12557658.333333334,
#    'total_trade_count': 909,
#    'daily_trade_count': 18.9375,
#    'total_return': -37.03605600000001,
#    'annual_return': -185.18028000000007,
#    'daily_return': -0.9475975440990325,
#    'return_std': 0.9067580380647037,
#    'sharpe_ratio': -16.189675098047353,
#    'return_drawdown_ratio': -1.0121552983343554}),
#  ("{'boll_window': 110, 'boll_dev': 1}",
#   -22.329166927377283,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 0,
#    'loss_days': 48,
#    'capital': 1000000,
#    'end_balance': 409348.2799999999,
#    'max_drawdown': -578595.04,
#    'max_ddpercent': -58.56561082876699,
#    'max_drawdown_duration': 72,
#    'total_net_pnl': -590651.72,
#    'daily_net_pnl': -12305.244166666665,
#    'total_commission': 550251.72,
#    'daily_commission': 11463.5775,
#    'total_slippage': 136600.0,
#    'daily_slippage': 2845.8333333333335,
#    'total_turnover': 917086200.0,
#    'daily_turnover': 19105962.5,
#    'total_trade_count': 1366,
#    'daily_trade_count': 28.458333333333332,
#    'total_return': -59.06517200000001,
#    'annual_return': -295.32586000000003,
#    'daily_return': -1.8355395701059793,
#    'return_std': 1.2734938494474648,
#    'sharpe_ratio': -22.329166927377283,
#    'return_drawdown_ratio': -1.0085299404234616}),
#  ("{'boll_window': 110, 'boll_dev': 2}",
#   -22.949388789296798,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 1,
#    'loss_days': 47,
#    'capital': 1000000,
#    'end_balance': 788931.7999999999,
#    'max_drawdown': -206829.80000000005,
#    'max_ddpercent': -20.771015873679005,
#    'max_drawdown_duration': 72,
#    'total_net_pnl': -211068.19999999998,
#    'daily_net_pnl': -4397.254166666667,
#    'total_commission': 220468.19999999995,
#    'daily_commission': 4593.087499999999,
#    'total_slippage': 54800.0,
#    'daily_slippage': 1141.6666666666667,
#    'total_turnover': 367447000.0,
#    'daily_turnover': 7655145.833333333,
#    'total_trade_count': 548,
#    'daily_trade_count': 11.416666666666666,
#    'total_return': -21.106820000000003,
#    'annual_return': -105.53410000000001,
#    'daily_return': -0.4850583185921942,
#    'return_std': 0.3274375290941251,
#    'sharpe_ratio': -22.949388789296798,
#    'return_drawdown_ratio': -1.0161669572813974}),
#  ("{'boll_window': 10, 'boll_dev': 2}",
#   -40.203243097767846,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 0,
#    'loss_days': 48,
#    'capital': 1000000,
#    'end_balance': 247391.43999999983,
#    'max_drawdown': -734790.6800000002,
#    'max_ddpercent': -74.81206031321362,
#    'max_drawdown_duration': 72,
#    'total_net_pnl': -752608.5599999998,
#    'daily_net_pnl': -15679.344999999996,
#    'total_commission': 672808.5599999998,
#    'daily_commission': 14016.844999999996,
#    'total_slippage': 166200.0,
#    'daily_slippage': 3462.5,
#    'total_turnover': 1121347600.0,
#    'daily_turnover': 23361408.333333332,
#    'total_trade_count': 1662,
#    'daily_trade_count': 34.625,
#    'total_return': -75.26085600000002,
#    'annual_return': -376.3042800000001,
#    'daily_return': -2.872510187262923,
#    'return_std': 1.1068941965727277,
#    'sharpe_ratio': -40.203243097767846,
#    'return_drawdown_ratio': -1.0059989750971627})]

# %%
engine.run_bf_optimization(setting)
# Out:
# 2023-12-16 09:54:41.698811	开始执行穷举算法优化
# 2023-12-16 09:54:41.698811	参数优化空间：50
# 100%|██████████| 50/50 [00:32<00:00,  1.52it/s]
# 2023-12-16 09:55:14.729180	穷举算法优化完成，耗时33秒
# 2023-12-16 09:55:15.349208	参数：{'boll_window': 510, 'boll_dev': 4}, 目标：2.7833951895449065
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 410, 'boll_dev': 4}, 目标：2.3799976371979814
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 710, 'boll_dev': 5}, 目标：2.3431749676275566
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 910, 'boll_dev': 5}, 目标：2.020534257651383
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 610, 'boll_dev': 5}, 目标：1.9816325605593867
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 810, 'boll_dev': 5}, 目标：1.7476954558605478
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 610, 'boll_dev': 4}, 目标：1.2705943359457084
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 510, 'boll_dev': 5}, 目标：1.0960748265484024
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 710, 'boll_dev': 4}, 目标：0.9952521499609477
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 310, 'boll_dev': 4}, 目标：0.7954647629759614
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：0
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：0
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 10, 'boll_dev': 4}, 目标：0
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 10, 'boll_dev': 5}, 目标：0
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 710, 'boll_dev': 3}, 目标：-0.14237932837585218
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 410, 'boll_dev': 5}, 目标：-0.18442436880287513
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 110, 'boll_dev': 5}, 目标：-0.29005398393739995
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 610, 'boll_dev': 3}, 目标：-0.49884761105824665
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 910, 'boll_dev': 3}, 目标：-0.6297957247799213
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 310, 'boll_dev': 5}, 目标：-0.8545735181231728
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 910, 'boll_dev': 4}, 目标：-0.9491403366970841
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 510, 'boll_dev': 3}, 目标：-1.0168405765260236
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 810, 'boll_dev': 3}, 目标：-1.19299580133557
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 810, 'boll_dev': 4}, 目标：-1.1942596665984118
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 410, 'boll_dev': 3}, 目标：-1.2791495934402648
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 210, 'boll_dev': 5}, 目标：-1.907513956738202
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 210, 'boll_dev': 4}, 目标：-1.9609753312313094
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 310, 'boll_dev': 3}, 目标：-2.710775847667906
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 110, 'boll_dev': 4}, 目标：-3.159923714077136
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 810, 'boll_dev': 2}, 目标：-3.3767250990109963
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 910, 'boll_dev': 2}, 目标：-3.404627594352048
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 710, 'boll_dev': 2}, 目标：-4.1444868247244155
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 610, 'boll_dev': 2}, 目标：-4.766706908025439
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 510, 'boll_dev': 2}, 目标：-6.4155727542128504
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 910, 'boll_dev': 1}, 目标：-6.841161374835698
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 210, 'boll_dev': 3}, 目标：-6.91485568568396
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 810, 'boll_dev': 1}, 目标：-7.602622535104136
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 710, 'boll_dev': 1}, 目标：-8.235579210665888
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 410, 'boll_dev': 2}, 目标：-8.394231182573542
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 610, 'boll_dev': 1}, 目标：-8.99995837089869
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 310, 'boll_dev': 2}, 目标：-9.50955779439599
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 510, 'boll_dev': 1}, 目标：-11.062300726540379
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 410, 'boll_dev': 1}, 目标：-11.594215997433313
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 310, 'boll_dev': 1}, 目标：-11.890326670842793
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 110, 'boll_dev': 3}, 目标：-13.140646968959084
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 210, 'boll_dev': 2}, 目标：-14.33857590034668
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 210, 'boll_dev': 1}, 目标：-16.189675098047353
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 110, 'boll_dev': 1}, 目标：-22.329166927377283
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 110, 'boll_dev': 2}, 目标：-22.949388789296798
# 2023-12-16 09:55:15.350206	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：-40.203243097767846
# [("{'boll_window': 510, 'boll_dev': 4}",
#   2.7833951895449065,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 13,
#    'loss_days': 4,
#    'capital': 1000000,
#    'end_balance': 1011463.04,
#    'max_drawdown': -3245.399999999907,
#    'max_ddpercent': -0.3224869449128531,
#    'max_drawdown_duration': 7,
#    'total_net_pnl': 11463.04,
#    'daily_net_pnl': 238.81333333333336,
#    'total_commission': 9336.96,
#    'daily_commission': 194.51999999999998,
#    'total_slippage': 2400.0,
#    'daily_slippage': 50.0,
#    'total_turnover': 15561600.0,
#    'daily_turnover': 324200.0,
#    'total_trade_count': 24,
#    'daily_trade_count': 0.5,
#    'total_return': 1.146303999999998,
#    'annual_return': 5.73151999999999,
#    'daily_return': 0.023745494095169992,
#    'return_std': 0.1321636302649451,
#    'sharpe_ratio': 2.7833951895449065,
#    'return_drawdown_ratio': 3.554574900108803}),
#  ("{'boll_window': 410, 'boll_dev': 4}",
#   2.3799976371979814,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 12,
#    'loss_days': 3,
#    'capital': 1000000,
#    'end_balance': 1008801.48,
#    'max_drawdown': -4930.160000000033,
#    'max_ddpercent': -0.4905849748390847,
#    'max_drawdown_duration': 32,
#    'total_net_pnl': 8801.48,
#    'daily_net_pnl': 183.36416666666665,
#    'total_commission': 9398.519999999999,
#    'daily_commission': 195.80249999999998,
#    'total_slippage': 2400.0,
#    'daily_slippage': 50.0,
#    'total_turnover': 15664200.0,
#    'daily_turnover': 326337.5,
#    'total_trade_count': 24,
#    'daily_trade_count': 0.5,
#    'total_return': 0.8801480000000028,
#    'annual_return': 4.400740000000014,
#    'daily_return': 0.018256193243974102,
#    'return_std': 0.11883361780526733,
#    'sharpe_ratio': 2.3799976371979814,
#    'return_drawdown_ratio': 1.794078590133539}),
#  ("{'boll_window': 710, 'boll_dev': 5}",
#   2.3431749676275566,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1003180.48,
#    'max_drawdown': -302.2399999999907,
#    'max_ddpercent': -0.030119103595524863,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 3180.48,
#    'daily_net_pnl': 66.26,
#    'total_commission': 1619.5199999999998,
#    'daily_commission': 33.739999999999995,
#    'total_slippage': 400.0,
#    'daily_slippage': 8.333333333333334,
#    'total_turnover': 2699200.0,
#    'daily_turnover': 56233.333333333336,
#    'total_trade_count': 4,
#    'daily_trade_count': 0.08333333333333333,
#    'total_return': 0.318047999999993,
#    'annual_return': 1.590239999999965,
#    'daily_return': 0.006615485358266213,
#    'return_std': 0.04373837203559025,
#    'sharpe_ratio': 2.3431749676275566,
#    'return_drawdown_ratio': 10.559676817448478}),
#  ("{'boll_window': 910, 'boll_dev': 5}",
#   2.020534257651383,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 1,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1001001.28,
#    'max_drawdown': -100.19999999995343,
#    'max_ddpercent': -0.010008975313866625,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 1001.28,
#    'daily_net_pnl': 20.86,
#    'total_commission': 798.72,
#    'daily_commission': 16.64,
#    'total_slippage': 200.0,
#    'daily_slippage': 4.166666666666667,
#    'total_turnover': 1331200.0,
#    'daily_turnover': 27733.333333333332,
#    'total_trade_count': 2,
#    'daily_trade_count': 0.041666666666666664,
#    'total_return': 0.10012800000001043,
#    'annual_return': 0.5006400000000522,
#    'daily_return': 0.0020849563615514665,
#    'return_std': 0.015985873509007886,
#    'sharpe_ratio': 2.020534257651383,
#    'return_drawdown_ratio': 10.00382125643683}),
#  ("{'boll_window': 610, 'boll_dev': 5}",
#   1.9816325605593867,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1002585.16,
#    'max_drawdown': -697.9199999999255,
#    'max_ddpercent': -0.06956361708002945,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 2585.16,
#    'daily_net_pnl': 53.857499999999995,
#    'total_commission': 1614.84,
#    'daily_commission': 33.6425,
#    'total_slippage': 400.0,
#    'daily_slippage': 8.333333333333334,
#    'total_turnover': 2691400.0,
#    'daily_turnover': 56070.833333333336,
#    'total_trade_count': 4,
#    'daily_trade_count': 0.08333333333333333,
#    'total_return': 0.2585159999999975,
#    'annual_return': 1.2925799999999876,
#    'daily_return': 0.005378800461800533,
#    'return_std': 0.04205018634785785,
#    'sharpe_ratio': 1.9816325605593867,
#    'return_drawdown_ratio': 3.7162529904474035}),
#  ("{'boll_window': 810, 'boll_dev': 5}",
#   1.7476954558605478,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 1,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1000401.4,
#    'max_drawdown': -100.19999999995343,
#    'max_ddpercent': -0.010014976487789068,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 401.40000000000003,
#    'daily_net_pnl': 8.3625,
#    'total_commission': 798.5999999999999,
#    'daily_commission': 16.6375,
#    'total_slippage': 200.0,
#    'daily_slippage': 4.166666666666667,
#    'total_turnover': 1331000.0,
#    'daily_turnover': 27729.166666666668,
#    'total_trade_count': 2,
#    'daily_trade_count': 0.041666666666666664,
#    'total_return': 0.04014000000001072,
#    'annual_return': 0.2007000000000536,
#    'daily_return': 0.0008360822095242206,
#    'return_std': 0.0074112053394409785,
#    'sharpe_ratio': 1.7476954558605478,
#    'return_drawdown_ratio': 4.007997427547844}),
#  ("{'boll_window': 610, 'boll_dev': 4}",
#   1.2705943359457084,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 10,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 1003487.36,
#    'max_drawdown': -9487.119999999995,
#    'max_ddpercent': -0.946349344227202,
#    'max_drawdown_duration': 6,
#    'total_net_pnl': 3487.3600000000015,
#    'daily_net_pnl': 72.65333333333336,
#    'total_commission': 7112.639999999999,
#    'daily_commission': 148.17999999999998,
#    'total_slippage': 1800.0,
#    'daily_slippage': 37.5,
#    'total_turnover': 11854400.0,
#    'daily_turnover': 246966.66666666666,
#    'total_trade_count': 18,
#    'daily_trade_count': 0.375,
#    'total_return': 0.34873600000000504,
#    'annual_return': 1.7436800000000252,
#    'daily_return': 0.013374262487239242,
#    'return_std': 0.16306792629397485,
#    'sharpe_ratio': 1.2705943359457084,
#    'return_drawdown_ratio': 0.3685066219227808}),
#  ("{'boll_window': 510, 'boll_dev': 5}",
#   1.0960748265484024,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 3,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1002470.64,
#    'max_drawdown': -3074.640000000014,
#    'max_ddpercent': -0.3065501372548283,
#    'max_drawdown_duration': 6,
#    'total_net_pnl': 2470.6400000000003,
#    'daily_net_pnl': 51.47166666666667,
#    'total_commission': 3129.3599999999997,
#    'daily_commission': 65.195,
#    'total_slippage': 800.0,
#    'daily_slippage': 16.666666666666668,
#    'total_turnover': 5215600.0,
#    'daily_turnover': 108658.33333333333,
#    'total_trade_count': 8,
#    'daily_trade_count': 0.16666666666666666,
#    'total_return': 0.24706400000000794,
#    'annual_return': 1.2353200000000397,
#    'daily_return': 0.005140818722247132,
#    'return_std': 0.07266038710088084,
#    'sharpe_ratio': 1.0960748265484024,
#    'return_drawdown_ratio': 0.8059497288517902}),
#  ("{'boll_window': 710, 'boll_dev': 4}",
#   0.9952521499609477,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 1002275.44,
#    'max_drawdown': -9487.119999999995,
#    'max_ddpercent': -0.9463495707854735,
#    'max_drawdown_duration': 6,
#    'total_net_pnl': 2275.4400000000005,
#    'daily_net_pnl': 47.40500000000001,
#    'total_commission': 5524.5599999999995,
#    'daily_commission': 115.09499999999998,
#    'total_slippage': 1400.0,
#    'daily_slippage': 29.166666666666668,
#    'total_turnover': 9207600.0,
#    'daily_turnover': 191825.0,
#    'total_trade_count': 14,
#    'daily_trade_count': 0.2916666666666667,
#    'total_return': 0.22754400000000174,
#    'annual_return': 1.1377200000000087,
#    'daily_return': 0.010438581440659572,
#    'return_std': 0.16248526397773952,
#    'sharpe_ratio': 0.9952521499609477,
#    'return_drawdown_ratio': 0.24044391948224736}),
#  ("{'boll_window': 310, 'boll_dev': 4}",
#   0.7954647629759614,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 11,
#    'loss_days': 7,
#    'capital': 1000000,
#    'end_balance': 1003074.24,
#    'max_drawdown': -4908.119999999995,
#    'max_ddpercent': -0.49030202705561843,
#    'max_drawdown_duration': 48,
#    'total_net_pnl': 3074.2400000000025,
#    'daily_net_pnl': 64.04666666666672,
#    'total_commission': 10925.759999999998,
#    'daily_commission': 227.61999999999998,
#    'total_slippage': 2800.0,
#    'daily_slippage': 58.333333333333336,
#    'total_turnover': 18209600.0,
#    'daily_turnover': 379366.6666666667,
#    'total_trade_count': 28,
#    'daily_trade_count': 0.5833333333333334,
#    'total_return': 0.3074239999999895,
#    'annual_return': 1.5371199999999474,
#    'daily_return': 0.006394842055764424,
#    'return_std': 0.1245416161034948,
#    'sharpe_ratio': 0.7954647629759614,
#    'return_drawdown_ratio': 0.627009441193104}),
#  ("{'boll_window': 10, 'boll_dev': 1}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 3}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 4}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 10, 'boll_dev': 5}",
#   0,
#   {'start_date': '',
#    'end_date': '',
#    'total_days': 0,
#    'profit_days': 0,
#    'loss_days': 0,
#    'capital': 1000000,
#    'end_balance': 0,
#    'max_drawdown': 0,
#    'max_ddpercent': 0,
#    'max_drawdown_duration': 0,
#    'total_net_pnl': 0,
#    'daily_net_pnl': 0,
#    'total_commission': 0,
#    'daily_commission': 0,
#    'total_slippage': 0,
#    'daily_slippage': 0,
#    'total_turnover': 0,
#    'daily_turnover': 0,
#    'total_trade_count': 0,
#    'daily_trade_count': 0,
#    'total_return': 0,
#    'annual_return': 0,
#    'daily_return': 0,
#    'return_std': 0,
#    'sharpe_ratio': 0,
#    'return_drawdown_ratio': 0}),
#  ("{'boll_window': 710, 'boll_dev': 3}",
#   -0.14237932837585218,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 21,
#    'loss_days': 14,
#    'capital': 1000000,
#    'end_balance': 994817.0,
#    'max_drawdown': -16887.0,
#    'max_ddpercent': -1.6842289783848206,
#    'max_drawdown_duration': 40,
#    'total_net_pnl': -5182.999999999999,
#    'daily_net_pnl': -107.97916666666664,
#    'total_commission': 16683.0,
#    'daily_commission': 347.5625,
#    'total_slippage': 4100.0,
#    'daily_slippage': 85.41666666666667,
#    'total_turnover': 27805000.0,
#    'daily_turnover': 579270.8333333334,
#    'total_trade_count': 41,
#    'daily_trade_count': 0.8541666666666666,
#    'total_return': -0.5183000000000049,
#    'annual_return': -2.5915000000000243,
#    'daily_return': -0.002200582353189741,
#    'return_std': 0.23943978112787,
#    'sharpe_ratio': -0.14237932837585218,
#    'return_drawdown_ratio': -0.3077372534565079}),
#  ("{'boll_window': 410, 'boll_dev': 5}",
#   -0.18442436880287513,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 999689.16,
#    'max_drawdown': -3074.640000000014,
#    'max_ddpercent': -0.3074640000000014,
#    'max_drawdown_duration': 35,
#    'total_net_pnl': -310.8399999999997,
#    'daily_net_pnl': -6.475833333333327,
#    'total_commission': 2310.8399999999997,
#    'daily_commission': 48.14249999999999,
#    'total_slippage': 600.0,
#    'daily_slippage': 12.5,
#    'total_turnover': 3851400.0,
#    'daily_turnover': 80237.5,
#    'total_trade_count': 6,
#    'daily_trade_count': 0.125,
#    'total_return': -0.03108399999999234,
#    'annual_return': -0.1554199999999617,
#    'daily_return': -0.0006476840015965231,
#    'return_std': 0.054406461967496905,
#    'sharpe_ratio': -0.18442436880287513,
#    'return_drawdown_ratio': -0.10109801472690201}),
#  ("{'boll_window': 110, 'boll_dev': 5}",
#   -0.29005398393739995,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 4,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 999237.72,
#    'max_drawdown': -5280.640000000014,
#    'max_ddpercent': -0.5271326199165233,
#    'max_drawdown_duration': 7,
#    'total_net_pnl': -762.28,
#    'daily_net_pnl': -15.880833333333333,
#    'total_commission': 3962.2799999999997,
#    'daily_commission': 82.5475,
#    'total_slippage': 1000.0,
#    'daily_slippage': 20.833333333333332,
#    'total_turnover': 6603800.0,
#    'daily_turnover': 137579.16666666666,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.20833333333333334,
#    'total_return': -0.0762280000000004,
#    'annual_return': -0.38114000000000203,
#    'daily_return': -0.0015886889231876461,
#    'return_std': 0.08485269753285503,
#    'sharpe_ratio': -0.29005398393739995,
#    'return_drawdown_ratio': -0.14460877039268008}),
#  ("{'boll_window': 610, 'boll_dev': 3}",
#   -0.49884761105824665,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 18,
#    'loss_days': 18,
#    'capital': 1000000,
#    'end_balance': 992225.16,
#    'max_drawdown': -16899.560000000056,
#    'max_ddpercent': -1.6861204805756111,
#    'max_drawdown_duration': 40,
#    'total_net_pnl': -7774.839999999999,
#    'daily_net_pnl': -161.97583333333333,
#    'total_commission': 19674.839999999997,
#    'daily_commission': 409.8924999999999,
#    'total_slippage': 4900.0,
#    'daily_slippage': 102.08333333333333,
#    'total_turnover': 32791400.0,
#    'daily_turnover': 683154.1666666666,
#    'total_trade_count': 49,
#    'daily_trade_count': 1.0208333333333333,
#    'total_return': -0.777483999999995,
#    'annual_return': -3.8874199999999743,
#    'daily_return': -0.007635464247160276,
#    'return_std': 0.23712272216423225,
#    'sharpe_ratio': -0.49884761105824665,
#    'return_drawdown_ratio': -0.461108211991219}),
#  ("{'boll_window': 910, 'boll_dev': 3}",
#   -0.6297957247799213,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 17,
#    'loss_days': 12,
#    'capital': 1000000,
#    'end_balance': 992833.96,
#    'max_drawdown': -14074.359999999986,
#    'max_ddpercent': -1.4074432624072326,
#    'max_drawdown_duration': 63,
#    'total_net_pnl': -7166.04,
#    'daily_net_pnl': -149.2925,
#    'total_commission': 11366.039999999997,
#    'daily_commission': 236.79249999999993,
#    'total_slippage': 2800.0,
#    'daily_slippage': 58.333333333333336,
#    'total_turnover': 18943400.0,
#    'daily_turnover': 394654.1666666667,
#    'total_trade_count': 28,
#    'daily_trade_count': 0.5833333333333334,
#    'total_return': -0.7166039999999985,
#    'annual_return': -3.5830199999999923,
#    'daily_return': -0.009279532097564993,
#    'return_std': 0.22826114475150017,
#    'sharpe_ratio': -0.6297957247799213,
#    'return_drawdown_ratio': -0.5091530288576953}),
#  ("{'boll_window': 310, 'boll_dev': 5}",
#   -0.8545735181231728,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 998684.52,
#    'max_drawdown': -3074.640000000014,
#    'max_ddpercent': -0.3074640000000014,
#    'max_drawdown_duration': 35,
#    'total_net_pnl': -1315.48,
#    'daily_net_pnl': -27.405833333333334,
#    'total_commission': 1515.48,
#    'daily_commission': 31.5725,
#    'total_slippage': 400.0,
#    'daily_slippage': 8.333333333333334,
#    'total_turnover': 2525800.0,
#    'daily_turnover': 52620.833333333336,
#    'total_trade_count': 4,
#    'daily_trade_count': 0.08333333333333333,
#    'total_return': -0.13154800000000355,
#    'annual_return': -0.6577400000000178,
#    'daily_return': -0.0027423875070249296,
#    'return_std': 0.049714721639778,
#    'sharpe_ratio': -0.8545735181231728,
#    'return_drawdown_ratio': -0.4278484635599711}),
#  ("{'boll_window': 910, 'boll_dev': 4}",
#   -0.9491403366970841,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 993552.52,
#    'max_drawdown': -13360.959999999963,
#    'max_ddpercent': -1.3360959999999964,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -6447.48,
#    'daily_net_pnl': -134.3225,
#    'total_commission': 4647.48,
#    'daily_commission': 96.82249999999999,
#    'total_slippage': 1200.0,
#    'daily_slippage': 25.0,
#    'total_turnover': 7745800.0,
#    'daily_turnover': 161370.83333333334,
#    'total_trade_count': 12,
#    'daily_trade_count': 0.25,
#    'total_return': -0.644747999999995,
#    'annual_return': -3.223739999999975,
#    'daily_return': -0.01347573911251908,
#    'return_std': 0.21995193394579773,
#    'sharpe_ratio': -0.9491403366970841,
#    'return_drawdown_ratio': -0.48256113333173417}),
#  ("{'boll_window': 510, 'boll_dev': 3}",
#   -1.0168405765260236,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 17,
#    'loss_days': 21,
#    'capital': 1000000,
#    'end_balance': 989781.12,
#    'max_drawdown': -14626.520000000019,
#    'max_ddpercent': -1.4656977786118686,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -10218.879999999997,
#    'daily_net_pnl': -212.8933333333333,
#    'total_commission': 22718.879999999997,
#    'daily_commission': 473.30999999999995,
#    'total_slippage': 5700.0,
#    'daily_slippage': 118.75,
#    'total_turnover': 37864800.0,
#    'daily_turnover': 788850.0,
#    'total_trade_count': 57,
#    'daily_trade_count': 1.1875,
#    'total_return': -1.0218880000000041,
#    'annual_return': -5.109440000000021,
#    'daily_return': -0.012773442498966297,
#    'return_std': 0.19460800921713972,
#    'sharpe_ratio': -1.0168405765260236,
#    'return_drawdown_ratio': -0.6972023939122106}),
#  ("{'boll_window': 810, 'boll_dev': 3}",
#   -1.19299580133557,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 15,
#    'loss_days': 15,
#    'capital': 1000000,
#    'end_balance': 988931.48,
#    'max_drawdown': -17484.31999999995,
#    'max_ddpercent': -1.7484406023277586,
#    'max_drawdown_duration': 63,
#    'total_net_pnl': -11068.519999999997,
#    'daily_net_pnl': -230.5941666666666,
#    'total_commission': 11768.52,
#    'daily_commission': 245.1775,
#    'total_slippage': 2900.0,
#    'daily_slippage': 60.416666666666664,
#    'total_turnover': 19614200.0,
#    'daily_turnover': 408629.1666666667,
#    'total_trade_count': 29,
#    'daily_trade_count': 0.6041666666666666,
#    'total_return': -1.1068520000000026,
#    'annual_return': -5.534260000000013,
#    'daily_return': -0.01748451641249715,
#    'return_std': 0.22704938544220063,
#    'sharpe_ratio': -1.19299580133557,
#    'return_drawdown_ratio': -0.6330509589667574}),
#  ("{'boll_window': 810, 'boll_dev': 4}",
#   -1.1942596665984118,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 8,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 991981.6,
#    'max_drawdown': -14731.76000000001,
#    'max_ddpercent': -1.473176000000001,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -8018.400000000001,
#    'daily_net_pnl': -167.05,
#    'total_commission': 3818.3999999999996,
#    'daily_commission': 79.55,
#    'total_slippage': 1000.0,
#    'daily_slippage': 20.833333333333332,
#    'total_turnover': 6364000.0,
#    'daily_turnover': 132583.33333333334,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.20833333333333334,
#    'total_return': -0.8018399999999981,
#    'annual_return': -4.00919999999999,
#    'daily_return': -0.016772333867468354,
#    'return_std': 0.21757067265197705,
#    'sharpe_ratio': -1.1942596665984118,
#    'return_drawdown_ratio': -0.5442934177586368}),
#  ("{'boll_window': 410, 'boll_dev': 3}",
#   -1.2791495934402648,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 18,
#    'loss_days': 20,
#    'capital': 1000000,
#    'end_balance': 988791.84,
#    'max_drawdown': -15177.479999999981,
#    'max_ddpercent': -1.5195844481973335,
#    'max_drawdown_duration': 62,
#    'total_net_pnl': -11208.16,
#    'daily_net_pnl': -233.50333333333333,
#    'total_commission': 24608.159999999996,
#    'daily_commission': 512.67,
#    'total_slippage': 6200.0,
#    'daily_slippage': 129.16666666666666,
#    'total_turnover': 41013600.0,
#    'daily_turnover': 854450.0,
#    'total_trade_count': 62,
#    'daily_trade_count': 1.2916666666666667,
#    'total_return': -1.1208160000000023,
#    'annual_return': -5.604080000000011,
#    'daily_return': -0.014856762359709026,
#    'return_std': 0.1799320220020891,
#    'sharpe_ratio': -1.2791495934402648,
#    'return_drawdown_ratio': -0.7375805940430715}),
#  ("{'boll_window': 210, 'boll_dev': 5}",
#   -1.907513956738202,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 3,
#    'loss_days': 4,
#    'capital': 1000000,
#    'end_balance': 993983.04,
#    'max_drawdown': -9911.79999999993,
#    'max_ddpercent': -0.9896170779564349,
#    'max_drawdown_duration': 40,
#    'total_net_pnl': -6016.96,
#    'daily_net_pnl': -125.35333333333334,
#    'total_commission': 3816.96,
#    'daily_commission': 79.52,
#    'total_slippage': 1000.0,
#    'daily_slippage': 20.833333333333332,
#    'total_turnover': 6361600.0,
#    'daily_turnover': 132533.33333333334,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.20833333333333334,
#    'total_return': -0.601695999999996,
#    'annual_return': -3.00847999999998,
#    'daily_return': -0.012573197594525479,
#    'return_std': 0.10211361174088777,
#    'sharpe_ratio': -1.907513956738202,
#    'return_drawdown_ratio': -0.6080089091050266}),
#  ("{'boll_window': 210, 'boll_dev': 4}",
#   -1.9609753312313094,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 8,
#    'loss_days': 8,
#    'capital': 1000000,
#    'end_balance': 992914.88,
#    'max_drawdown': -13195.560000000056,
#    'max_ddpercent': -1.3145673221777268,
#    'max_drawdown_duration': 48,
#    'total_net_pnl': -7085.12,
#    'daily_net_pnl': -147.60666666666665,
#    'total_commission': 11085.12,
#    'daily_commission': 230.94000000000003,
#    'total_slippage': 2800.0,
#    'daily_slippage': 58.333333333333336,
#    'total_turnover': 18475200.0,
#    'daily_turnover': 384900.0,
#    'total_trade_count': 28,
#    'daily_trade_count': 0.5833333333333334,
#    'total_return': -0.7085119999999945,
#    'annual_return': -3.5425599999999724,
#    'daily_return': -0.014813205523789367,
#    'return_std': 0.11702604797493321,
#    'sharpe_ratio': -1.9609753312313094,
#    'return_drawdown_ratio': -0.5389697340310161}),
#  ("{'boll_window': 310, 'boll_dev': 3}",
#   -2.710775847667906,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 17,
#    'loss_days': 23,
#    'capital': 1000000,
#    'end_balance': 981776.92,
#    'max_drawdown': -24889.76000000001,
#    'max_ddpercent': -2.4857731310361233,
#    'max_drawdown_duration': 61,
#    'total_net_pnl': -18223.079999999998,
#    'daily_net_pnl': -379.6475,
#    'total_commission': 31423.079999999998,
#    'daily_commission': 654.6474999999999,
#    'total_slippage': 7800.0,
#    'daily_slippage': 162.5,
#    'total_turnover': 52371800.0,
#    'daily_turnover': 1091079.1666666667,
#    'total_trade_count': 78,
#    'daily_trade_count': 1.625,
#    'total_return': -1.8223079999999947,
#    'annual_return': -9.111539999999973,
#    'daily_return': -0.029689513895728922,
#    'return_std': 0.16967392265070635,
#    'sharpe_ratio': -2.710775847667906,
#    'return_drawdown_ratio': -0.7330950589366206}),
#  ("{'boll_window': 110, 'boll_dev': 4}",
#   -3.159923714077136,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 12,
#    'loss_days': 15,
#    'capital': 1000000,
#    'end_balance': 987112.6,
#    'max_drawdown': -17014.280000000028,
#    'max_ddpercent': -1.700909562765272,
#    'max_drawdown_duration': 66,
#    'total_net_pnl': -12887.399999999998,
#    'daily_net_pnl': -268.48749999999995,
#    'total_commission': 23687.399999999994,
#    'daily_commission': 493.4874999999999,
#    'total_slippage': 5800.0,
#    'daily_slippage': 120.83333333333333,
#    'total_turnover': 39479000.0,
#    'daily_turnover': 822479.1666666666,
#    'total_trade_count': 58,
#    'daily_trade_count': 1.2083333333333333,
#    'total_return': -1.2887399999999993,
#    'annual_return': -6.443699999999997,
#    'daily_return': -0.026818162770958085,
#    'return_std': 0.13147950037538783,
#    'sharpe_ratio': -3.159923714077136,
#    'return_drawdown_ratio': -0.7576769677894082}),
#  ("{'boll_window': 810, 'boll_dev': 2}",
#   -3.3767250990109963,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 20,
#    'loss_days': 25,
#    'capital': 1000000,
#    'end_balance': 967858.52,
#    'max_drawdown': -38694.55999999994,
#    'max_ddpercent': -3.862004802414408,
#    'max_drawdown_duration': 61,
#    'total_net_pnl': -32141.479999999996,
#    'daily_net_pnl': -669.6141666666666,
#    'total_commission': 38841.479999999996,
#    'daily_commission': 809.1974999999999,
#    'total_slippage': 9700.0,
#    'daily_slippage': 202.08333333333334,
#    'total_turnover': 64735800.0,
#    'daily_turnover': 1348662.5,
#    'total_trade_count': 97,
#    'daily_trade_count': 2.0208333333333335,
#    'total_return': -3.2141479999999945,
#    'annual_return': -16.070739999999972,
#    'daily_return': -0.06027438139436128,
#    'return_std': 0.27653026941599457,
#    'sharpe_ratio': -3.3767250990109963,
#    'return_drawdown_ratio': -0.8322485766953492}),
#  ("{'boll_window': 910, 'boll_dev': 2}",
#   -3.404627594352048,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 20,
#    'loss_days': 23,
#    'capital': 1000000,
#    'end_balance': 968377.0,
#    'max_drawdown': -38782.080000000075,
#    'max_ddpercent': -3.8745755079697757,
#    'max_drawdown_duration': 60,
#    'total_net_pnl': -31623.0,
#    'daily_net_pnl': -658.8125,
#    'total_commission': 35523.0,
#    'daily_commission': 740.0625,
#    'total_slippage': 8900.0,
#    'daily_slippage': 185.41666666666666,
#    'total_turnover': 59205000.0,
#    'daily_turnover': 1233437.5,
#    'total_trade_count': 89,
#    'daily_trade_count': 1.8541666666666667,
#    'total_return': -3.1622999999999957,
#    'annual_return': -15.811499999999977,
#    'daily_return': -0.059158642444913576,
#    'return_std': 0.26918707626464455,
#    'sharpe_ratio': -3.404627594352048,
#    'return_drawdown_ratio': -0.8161668274357614}),
#  ("{'boll_window': 710, 'boll_dev': 2}",
#   -4.1444868247244155,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 19,
#    'loss_days': 25,
#    'capital': 1000000,
#    'end_balance': 960022.76,
#    'max_drawdown': -41946.04000000004,
#    'max_ddpercent': -4.204211126930375,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -39977.23999999999,
#    'daily_net_pnl': -832.8591666666665,
#    'total_commission': 41877.23999999999,
#    'daily_commission': 872.4424999999998,
#    'total_slippage': 10500.0,
#    'daily_slippage': 218.75,
#    'total_turnover': 69795400.0,
#    'daily_turnover': 1454070.8333333333,
#    'total_trade_count': 105,
#    'daily_trade_count': 2.1875,
#    'total_return': -3.9977240000000025,
#    'annual_return': -19.988620000000015,
#    'daily_return': -0.07511067912555686,
#    'return_std': 0.2807608484989734,
#    'sharpe_ratio': -4.1444868247244155,
#    'return_drawdown_ratio': -0.9508856428242378}),
#  ("{'boll_window': 610, 'boll_dev': 2}",
#   -4.766706908025439,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 16,
#    'loss_days': 29,
#    'capital': 1000000,
#    'end_balance': 954241.36,
#    'max_drawdown': -49359.80000000005,
#    'max_ddpercent': -4.947288710425844,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -45758.64,
#    'daily_net_pnl': -953.305,
#    'total_commission': 46658.64,
#    'daily_commission': 972.055,
#    'total_slippage': 11700.0,
#    'daily_slippage': 243.75,
#    'total_turnover': 77764400.0,
#    'daily_turnover': 1620091.6666666667,
#    'total_trade_count': 117,
#    'daily_trade_count': 2.4375,
#    'total_return': -4.575863999999996,
#    'annual_return': -22.87931999999998,
#    'daily_return': -0.08769475237743025,
#    'return_std': 0.2850104460467139,
#    'sharpe_ratio': -4.766706908025439,
#    'return_drawdown_ratio': -0.9249235829631061}),
#  ("{'boll_window': 510, 'boll_dev': 2}",
#   -6.4155727542128504,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 15,
#    'loss_days': 32,
#    'capital': 1000000,
#    'end_balance': 944480.64,
#    'max_drawdown': -56417.16000000003,
#    'max_ddpercent': -5.659962814519965,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -55519.36,
#    'daily_net_pnl': -1156.6533333333334,
#    'total_commission': 56019.36,
#    'daily_commission': 1167.07,
#    'total_slippage': 14100.0,
#    'daily_slippage': 293.75,
#    'total_turnover': 93365600.0,
#    'daily_turnover': 1945116.6666666667,
#    'total_trade_count': 141,
#    'daily_trade_count': 2.9375,
#    'total_return': -5.551936000000001,
#    'annual_return': -27.759680000000007,
#    'daily_return': -0.1091144362098882,
#    'return_std': 0.2634828785905078,
#    'sharpe_ratio': -6.4155727542128504,
#    'return_drawdown_ratio': -0.9809138649740182}),
#  ("{'boll_window': 910, 'boll_dev': 1}",
#   -6.841161374835698,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 13,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 904404.0,
#    'max_drawdown': -102974.88,
#    'max_ddpercent': -10.323794680653455,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -95595.99999999999,
#    'daily_net_pnl': -1991.583333333333,
#    'total_commission': 106896.0,
#    'daily_commission': 2227.0,
#    'total_slippage': 26900.0,
#    'daily_slippage': 560.4166666666666,
#    'total_turnover': 178160000.0,
#    'daily_turnover': 3711666.6666666665,
#    'total_trade_count': 269,
#    'daily_trade_count': 5.604166666666667,
#    'total_return': -9.559600000000001,
#    'annual_return': -47.798,
#    'daily_return': -0.19888601564543693,
#    'return_std': 0.4503809714074021,
#    'sharpe_ratio': -6.841161374835698,
#    'return_drawdown_ratio': -0.9259773460929501}),
#  ("{'boll_window': 210, 'boll_dev': 3}",
#   -6.91485568568396,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 11,
#    'loss_days': 29,
#    'capital': 1000000,
#    'end_balance': 962381.4,
#    'max_drawdown': -36867.07999999996,
#    'max_ddpercent': -3.7020033451007484,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -37618.6,
#    'daily_net_pnl': -783.7208333333333,
#    'total_commission': 43218.59999999999,
#    'daily_commission': 900.3874999999998,
#    'total_slippage': 10600.0,
#    'daily_slippage': 220.83333333333334,
#    'total_turnover': 72031000.0,
#    'daily_turnover': 1500645.8333333333,
#    'total_trade_count': 106,
#    'daily_trade_count': 2.2083333333333335,
#    'total_return': -3.7618599999999947,
#    'annual_return': -18.809299999999972,
#    'daily_return': -0.07125883830090768,
#    'return_std': 0.15964717504134268,
#    'sharpe_ratio': -6.91485568568396,
#    'return_drawdown_ratio': -1.0161687198306995}),
#  ("{'boll_window': 810, 'boll_dev': 1}",
#   -7.602622535104136,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 14,
#    'loss_days': 34,
#    'capital': 1000000,
#    'end_balance': 894918.24,
#    'max_drawdown': -110621.80000000005,
#    'max_ddpercent': -11.095624431160408,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -105081.76,
#    'daily_net_pnl': -2189.2033333333334,
#    'total_commission': 116381.76,
#    'daily_commission': 2424.62,
#    'total_slippage': 29300.0,
#    'daily_slippage': 610.4166666666666,
#    'total_turnover': 193969600.0,
#    'daily_turnover': 4041033.3333333335,
#    'total_trade_count': 293,
#    'daily_trade_count': 6.104166666666667,
#    'total_return': -10.508176000000002,
#    'annual_return': -52.540880000000016,
#    'daily_return': -0.21987624237803619,
#    'return_std': 0.44804382752122796,
#    'sharpe_ratio': -7.602622535104136,
#    'return_drawdown_ratio': -0.9470558475726122}),
#  ("{'boll_window': 710, 'boll_dev': 1}",
#   -8.235579210665888,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 12,
#    'loss_days': 36,
#    'capital': 1000000,
#    'end_balance': 890247.12,
#    'max_drawdown': -117111.08000000007,
#    'max_ddpercent': -11.742025693011762,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -109752.87999999999,
#    'daily_net_pnl': -2286.518333333333,
#    'total_commission': 116252.87999999999,
#    'daily_commission': 2421.935,
#    'total_slippage': 29300.0,
#    'daily_slippage': 610.4166666666666,
#    'total_turnover': 193754800.0,
#    'daily_turnover': 4036558.3333333335,
#    'total_trade_count': 293,
#    'daily_trade_count': 6.104166666666667,
#    'total_return': -10.975288000000006,
#    'annual_return': -54.87644000000003,
#    'daily_return': -0.2318941994624852,
#    'return_std': 0.4362157655831416,
#    'sharpe_ratio': -8.235579210665888,
#    'return_drawdown_ratio': -0.93470141242596}),
#  ("{'boll_window': 410, 'boll_dev': 2}",
#   -8.394231182573542,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 10,
#    'loss_days': 36,
#    'capital': 1000000,
#    'end_balance': 942569.88,
#    'max_drawdown': -57627.95999999996,
#    'max_ddpercent': -5.780662408920495,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -57430.119999999995,
#    'daily_net_pnl': -1196.4608333333333,
#    'total_commission': 65130.119999999995,
#    'daily_commission': 1356.8774999999998,
#    'total_slippage': 16300.0,
#    'daily_slippage': 339.5833333333333,
#    'total_turnover': 108550200.0,
#    'daily_turnover': 2261462.5,
#    'total_trade_count': 163,
#    'daily_trade_count': 3.3958333333333335,
#    'total_return': -5.743012000000003,
#    'annual_return': -28.715060000000012,
#    'daily_return': -0.11571127761979272,
#    'return_std': 0.2135503973825248,
#    'sharpe_ratio': -8.394231182573542,
#    'return_drawdown_ratio': -0.99348683485436}),
#  ("{'boll_window': 610, 'boll_dev': 1}",
#   -8.99995837089869,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 11,
#    'loss_days': 37,
#    'capital': 1000000,
#    'end_balance': 874110.88,
#    'max_drawdown': -128554.23999999999,
#    'max_ddpercent': -12.899675563038468,
#    'max_drawdown_duration': 68,
#    'total_net_pnl': -125889.12,
#    'daily_net_pnl': -2622.69,
#    'total_commission': 135189.12,
#    'daily_commission': 2816.44,
#    'total_slippage': 34100.0,
#    'daily_slippage': 710.4166666666666,
#    'total_turnover': 225315200.0,
#    'daily_turnover': 4694066.666666667,
#    'total_trade_count': 341,
#    'daily_trade_count': 7.104166666666667,
#    'total_return': -12.588911999999997,
#    'annual_return': -62.94455999999998,
#    'daily_return': -0.2691640926114772,
#    'return_std': 0.46332127555260527,
#    'sharpe_ratio': -8.99995837089869,
#    'return_drawdown_ratio': -0.975909195427449}),
#  ("{'boll_window': 310, 'boll_dev': 2}",
#   -9.50955779439599,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 13,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 931763.72,
#    'max_drawdown': -70601.95999999996,
#    'max_ddpercent': -7.09139102913717,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -68236.28,
#    'daily_net_pnl': -1421.5891666666666,
#    'total_commission': 82136.28,
#    'daily_commission': 1711.1725,
#    'total_slippage': 20500.0,
#    'daily_slippage': 427.0833333333333,
#    'total_turnover': 136893800.0,
#    'daily_turnover': 2851954.1666666665,
#    'total_trade_count': 205,
#    'daily_trade_count': 4.270833333333333,
#    'total_return': -6.823628000000004,
#    'annual_return': -34.11814000000002,
#    'daily_return': -0.13805689933655146,
#    'return_std': 0.2249072285041869,
#    'sharpe_ratio': -9.50955779439599,
#    'return_drawdown_ratio': -0.9622411134801369}),
#  ("{'boll_window': 510, 'boll_dev': 1}",
#   -11.062300726540379,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 39,
#    'capital': 1000000,
#    'end_balance': 841614.6,
#    'max_drawdown': -154483.6399999999,
#    'max_ddpercent': -15.538503480228938,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -158385.39999999997,
#    'daily_net_pnl': -3299.6958333333328,
#    'total_commission': 164885.39999999997,
#    'daily_commission': 3435.1124999999993,
#    'total_slippage': 41500.0,
#    'daily_slippage': 864.5833333333334,
#    'total_turnover': 274809000.0,
#    'daily_turnover': 5725187.5,
#    'total_trade_count': 415,
#    'daily_trade_count': 8.645833333333334,
#    'total_return': -15.838540000000002,
#    'annual_return': -79.1927,
#    'daily_return': -0.34711491218983004,
#    'return_std': 0.4861087426076148,
#    'sharpe_ratio': -11.062300726540379,
#    'return_drawdown_ratio': -1.0193092288554575}),
#  ("{'boll_window': 410, 'boll_dev': 1}",
#   -11.594215997433313,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 7,
#    'loss_days': 41,
#    'capital': 1000000,
#    'end_balance': 812442.8,
#    'max_drawdown': -184822.4800000001,
#    'max_ddpercent': -18.583851864978442,
#    'max_drawdown_duration': 69,
#    'total_net_pnl': -187557.19999999998,
#    'daily_net_pnl': -3907.441666666666,
#    'total_commission': 191257.19999999998,
#    'daily_commission': 3984.5249999999996,
#    'total_slippage': 48100.0,
#    'daily_slippage': 1002.0833333333334,
#    'total_turnover': 318762000.0,
#    'daily_turnover': 6640875.0,
#    'total_trade_count': 481,
#    'daily_trade_count': 10.020833333333334,
#    'total_return': -18.755719999999997,
#    'annual_return': -93.77859999999998,
#    'daily_return': -0.42130718075513707,
#    'return_std': 0.5629412786732514,
#    'sharpe_ratio': -11.594215997433313,
#    'return_drawdown_ratio': -1.0092482514534806}),
#  ("{'boll_window': 310, 'boll_dev': 1}",
#   -11.890326670842793,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 6,
#    'loss_days': 42,
#    'capital': 1000000,
#    'end_balance': 758485.0800000001,
#    'max_drawdown': -238605.20000000007,
#    'max_ddpercent': -23.99167287896013,
#    'max_drawdown_duration': 63,
#    'total_net_pnl': -241514.91999999998,
#    'daily_net_pnl': -5031.560833333333,
#    'total_commission': 255814.91999999998,
#    'daily_commission': 5329.4775,
#    'total_slippage': 64500.0,
#    'daily_slippage': 1343.75,
#    'total_turnover': 426358200.0,
#    'daily_turnover': 8882462.5,
#    'total_trade_count': 645,
#    'daily_trade_count': 13.4375,
#    'total_return': -24.151491999999998,
#    'annual_return': -120.75745999999998,
#    'daily_return': -0.5644803213604112,
#    'return_std': 0.7354626813581809,
#    'sharpe_ratio': -11.890326670842793,
#    'return_drawdown_ratio': -1.0066614413195014}),
#  ("{'boll_window': 110, 'boll_dev': 3}",
#   -13.140646968959084,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 5,
#    'loss_days': 40,
#    'capital': 1000000,
#    'end_balance': 938457.52,
#    'max_drawdown': -63653.52000000002,
#    'max_ddpercent': -6.365576068277605,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': -61542.479999999996,
#    'daily_net_pnl': -1282.135,
#    'total_commission': 70542.48,
#    'daily_commission': 1469.635,
#    'total_slippage': 17400.0,
#    'daily_slippage': 362.5,
#    'total_turnover': 117570800.0,
#    'daily_turnover': 2449391.6666666665,
#    'total_trade_count': 174,
#    'daily_trade_count': 3.625,
#    'total_return': -6.1542479999999955,
#    'annual_return': -30.771239999999974,
#    'daily_return': -0.1322551814149413,
#    'return_std': 0.15591990752957066,
#    'sharpe_ratio': -13.140646968959084,
#    'return_drawdown_ratio': -0.9668014228388931}),
#  ("{'boll_window': 210, 'boll_dev': 2}",
#   -14.33857590034668,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 9,
#    'loss_days': 39,
#    'capital': 1000000,
#    'end_balance': 893369.8,
#    'max_drawdown': -103068.64000000001,
#    'max_ddpercent': -10.357980634430918,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': -106630.19999999998,
#    'daily_net_pnl': -2221.4624999999996,
#    'total_commission': 123130.2,
#    'daily_commission': 2565.2125,
#    'total_slippage': 30700.0,
#    'daily_slippage': 639.5833333333334,
#    'total_turnover': 205217000.0,
#    'daily_turnover': 4275354.166666667,
#    'total_trade_count': 307,
#    'daily_trade_count': 6.395833333333333,
#    'total_return': -10.663020000000001,
#    'annual_return': -53.3151,
#    'daily_return': -0.22459886824771394,
#    'return_std': 0.24266501285651337,
#    'sharpe_ratio': -14.33857590034668,
#    'return_drawdown_ratio': -1.02944969452396}),
#  ("{'boll_window': 210, 'boll_dev': 1}",
#   -16.189675098047353,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 2,
#    'loss_days': 46,
#    'capital': 1000000,
#    'end_balance': 629639.44,
#    'max_drawdown': -363083.88,
#    'max_ddpercent': -36.59127809828005,
#    'max_drawdown_duration': 70,
#    'total_net_pnl': -370360.55999999994,
#    'daily_net_pnl': -7715.844999999998,
#    'total_commission': 361660.55999999994,
#    'daily_commission': 7534.594999999998,
#    'total_slippage': 90900.0,
#    'daily_slippage': 1893.75,
#    'total_turnover': 602767600.0,
#    'daily_turnover': 12557658.333333334,
#    'total_trade_count': 909,
#    'daily_trade_count': 18.9375,
#    'total_return': -37.03605600000001,
#    'annual_return': -185.18028000000007,
#    'daily_return': -0.9475975440990325,
#    'return_std': 0.9067580380647037,
#    'sharpe_ratio': -16.189675098047353,
#    'return_drawdown_ratio': -1.0121552983343554}),
#  ("{'boll_window': 110, 'boll_dev': 1}",
#   -22.329166927377283,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 0,
#    'loss_days': 48,
#    'capital': 1000000,
#    'end_balance': 409348.2799999999,
#    'max_drawdown': -578595.04,
#    'max_ddpercent': -58.56561082876699,
#    'max_drawdown_duration': 72,
#    'total_net_pnl': -590651.72,
#    'daily_net_pnl': -12305.244166666665,
#    'total_commission': 550251.72,
#    'daily_commission': 11463.5775,
#    'total_slippage': 136600.0,
#    'daily_slippage': 2845.8333333333335,
#    'total_turnover': 917086200.0,
#    'daily_turnover': 19105962.5,
#    'total_trade_count': 1366,
#    'daily_trade_count': 28.458333333333332,
#    'total_return': -59.06517200000001,
#    'annual_return': -295.32586000000003,
#    'daily_return': -1.8355395701059793,
#    'return_std': 1.2734938494474648,
#    'sharpe_ratio': -22.329166927377283,
#    'return_drawdown_ratio': -1.0085299404234616}),
#  ("{'boll_window': 110, 'boll_dev': 2}",
#   -22.949388789296798,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 1,
#    'loss_days': 47,
#    'capital': 1000000,
#    'end_balance': 788931.7999999999,
#    'max_drawdown': -206829.80000000005,
#    'max_ddpercent': -20.771015873679005,
#    'max_drawdown_duration': 72,
#    'total_net_pnl': -211068.19999999998,
#    'daily_net_pnl': -4397.254166666667,
#    'total_commission': 220468.19999999995,
#    'daily_commission': 4593.087499999999,
#    'total_slippage': 54800.0,
#    'daily_slippage': 1141.6666666666667,
#    'total_turnover': 367447000.0,
#    'daily_turnover': 7655145.833333333,
#    'total_trade_count': 548,
#    'daily_trade_count': 11.416666666666666,
#    'total_return': -21.106820000000003,
#    'annual_return': -105.53410000000001,
#    'daily_return': -0.4850583185921942,
#    'return_std': 0.3274375290941251,
#    'sharpe_ratio': -22.949388789296798,
#    'return_drawdown_ratio': -1.0161669572813974}),
#  ("{'boll_window': 10, 'boll_dev': 2}",
#   -40.203243097767846,
#   {'start_date': datetime.date(2023, 4, 18),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 48,
#    'profit_days': 0,
#    'loss_days': 48,
#    'capital': 1000000,
#    'end_balance': 247391.43999999983,
#    'max_drawdown': -734790.6800000002,
#    'max_ddpercent': -74.81206031321362,
#    'max_drawdown_duration': 72,
#    'total_net_pnl': -752608.5599999998,
#    'daily_net_pnl': -15679.344999999996,
#    'total_commission': 672808.5599999998,
#    'daily_commission': 14016.844999999996,
#    'total_slippage': 166200.0,
#    'daily_slippage': 3462.5,
#    'total_turnover': 1121347600.0,
#    'daily_turnover': 23361408.333333332,
#    'total_trade_count': 1662,
#    'daily_trade_count': 34.625,
#    'total_return': -75.26085600000002,
#    'annual_return': -376.3042800000001,
#    'daily_return': -2.872510187262923,
#    'return_std': 1.1068941965727277,
#    'sharpe_ratio': -40.203243097767846,
#    'return_drawdown_ratio': -1.0059989750971627})]
