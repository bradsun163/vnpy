# %%
from vnpy.trader.optimize import OptimizationSetting
from vnpy_spreadtrading.backtesting import BacktestingEngine
from vnpy_spreadtrading.strategies.statistical_arbitrage_strategy import (
    StatisticalArbitrageStrategy, StatisticalArbitrageStrategyResearch
)
from vnpy_spreadtrading.base import LegData, SpreadData
from datetime import datetime
# Out:
# Print StatisticalArbitrageStrategyResearch is being deployed

# %% [markdown]
# # StatisticalArbitrageStrategy

# %%
# ---------------------SA纯碱---------------------: # Selected
spread = SpreadData(
    name="SA-Spread",
    legs=[LegData("SA307.CZCE"), LegData("SA308.CZCE")],
    variable_symbols={"A": "SA307.CZCE", "B": "SA308.CZCE"},
    variable_directions={"A": 1, "B": -1},
    price_formula="A-B",
    trading_multipliers={"SA307.CZCE": 1, "SA308.CZCE": 1},
    active_symbol="SA307.CZCE",
    min_volume=1,
    compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
)

engine = BacktestingEngine()
engine.set_parameters(
    spread=spread,
    interval="1m",
    start=datetime(2023, 1, 1), # max at 4,1
    end=datetime(2023, 6, 30),
    rate=0.0002,
    # rate = 0,
    # slippage=0.5,
    slippage=0.5,
    size=20,
    pricetick=1,
    capital=1_000_000,
)
engine.add_strategy(StatisticalArbitrageStrategyResearch, {"boll_window":510, "boll_dev":3})

engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()

# # ---------------------TA---------------------: # Abandoned
# spread = SpreadData(
#     name="PTA-Spread",
#     legs=[LegData("TA307.CZCE"), LegData("TA308.CZCE")],
#     variable_symbols={"A": "TA307.CZCE", "B": "TA308.CZCE"},
#     variable_directions={"A": 1, "B": -1},
#     price_formula="A-B",
#     trading_multipliers={"TA307.CZCE": 1, "TA308.CZCE": 1},
#     active_symbol="TA307.CZCE",
#     min_volume=1,
#     compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
# )

# engine = BacktestingEngine()
# engine.set_parameters(
#     spread=spread,
#     interval="1m",
#     start=datetime(2023, 1, 1), # max at 4,1
#     end=datetime(2023, 6, 30),
#     rate=0.001,
#     # rate = 0,
#     # slippage=0.5,
#     slippage=1,
#     size=5,
#     pricetick=2,
#     capital=1_000_000,
# )
# engine.add_strategy(StatisticalArbitrageStrategyResearch, {"boll_window":510, "boll_dev":4})

# engine.load_data()
# engine.run_backtesting()
# df = engine.calculate_result()
# engine.calculate_statistics()
# engine.show_chart()

# # ---------------------RM菜粕---------------------: Abandoned
# spread = SpreadData(
#     name="RM-Spread",
#     legs=[LegData("RM307.CZCE"), LegData("RM308.CZCE")],
#     variable_symbols={"A": "RM307.CZCE", "B": "RM308.CZCE"},
#     variable_directions={"A": 1, "B": -1},
#     price_formula="A-B",
#     trading_multipliers={"RM307.CZCE": 1, "RM308.CZCE": 1},
#     active_symbol="RM307.CZCE",
#     min_volume=1,
#     compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
# )

# engine = BacktestingEngine()
# engine.set_parameters(
#     spread=spread,
#     interval="1m",
#     start=datetime(2023, 1, 1), # max at 4,1
#     end=datetime(2023, 6, 30),
#     rate=0.0004,
#     # rate = 0,
#     # slippage=0.5,
#     slippage=0.5,
#     size=10,
#     pricetick=1,
#     capital=1_000_000,
# )
# engine.add_strategy(StatisticalArbitrageStrategyResearch, {"boll_window":510, "boll_dev":4})

# engine.load_data()
# engine.run_backtesting()
# df = engine.calculate_result()
# engine.calculate_statistics()
# engine.show_chart()

# # ---------------------FG---------------------: Abandoned
# spread = SpreadData(
#     name="FG-Spread",
#     legs=[LegData("FG307.CZCE"), LegData("FG308.CZCE")],
#     variable_symbols={"A": "FG307.CZCE", "B": "FG308.CZCE"},
#     variable_directions={"A": 1, "B": -1},
#     price_formula="A-B",
#     trading_multipliers={"FG307.CZCE": 1, "FG308.CZCE": 1},
#     active_symbol="FG307.CZCE",
#     min_volume=1,
#     compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
# )

# engine = BacktestingEngine()
# engine.set_parameters(
#     spread=spread,
#     interval="1m",
#     start=datetime(2023, 1, 1), # max at 4,1
#     end=datetime(2023, 6, 30),
#     rate=0.0006,
#     # rate = 0,
#     # slippage=0.5,
#     slippage=0.5,
#     size=20,
#     pricetick=1,
#     capital=1_000_000,
# )
# engine.add_strategy(StatisticalArbitrageStrategyResearch, {"boll_window":310, "boll_dev":4})

# engine.load_data()
# engine.run_backtesting()
# df = engine.calculate_result()
# engine.calculate_statistics()
# engine.show_chart()


# # ---------------------MA---------------------: Selected
# spread = SpreadData(
#     name="MA-Spread",
#     legs=[LegData("MA307.CZCE"), LegData("MA308.CZCE")],
#     variable_symbols={"A": "MA307.CZCE", "B": "MA308.CZCE"},
#     variable_directions={"A": 1, "B": -1},
#     price_formula="A-B",
#     trading_multipliers={"MA307.CZCE": 1, "MA308.CZCE": 1},
#     active_symbol="MA307.CZCE",
#     min_volume=1,
#     compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
# )

# engine = BacktestingEngine()
# engine.set_parameters(
#     spread=spread,
#     interval="1m",
#     start=datetime(2023, 1, 1), # max at 4,1
#     end=datetime(2023, 6, 30),
#     rate=0.0004,
#     # rate = 0,
#     # slippage=0.5,
#     slippage=0.5,
#     size=10,
#     pricetick=1,
#     capital=1_000_000,
# )
# engine.add_strategy(StatisticalArbitrageStrategyResearch, {"boll_window":710, "boll_dev":2})

# engine.load_data()
# engine.run_backtesting()
# df = engine.calculate_result()
# engine.calculate_statistics()
# engine.show_chart()



# # ---------------------FU---------------------: # No contract info
# spread = SpreadData(
#     name="FU-Spread",
#     legs=[LegData("FU307.CZCE"), LegData("FU308.CZCE")],
#     variable_symbols={"A": "FU307.CZCE", "B": "FU308.CZCE"},
#     variable_directions={"A": 1, "B": -1},
#     price_formula="A-B",
#     trading_multipliers={"FU307.CZCE": 1, "FU308.CZCE": 1},
#     active_symbol="FU307.CZCE",
#     min_volume=1,
#     compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
# )

# engine = BacktestingEngine()
# engine.set_parameters(
#     spread=spread,
#     interval="1m",
#     start=datetime(2023, 1, 1), # max at 4,1
#     end=datetime(2023, 6, 30),
#     rate=0.0006,
#     # rate = 0,
#     # slippage=0.5,
#     slippage=0.5,
#     size=20,
#     pricetick=1,
#     capital=1_000_000,
# )
# engine.add_strategy(StatisticalArbitrageStrategyResearch, {"boll_window":510, "boll_dev":4})

# engine.load_data()
# engine.run_backtesting()
# df = engine.calculate_result()
# engine.calculate_statistics()
# engine.show_chart()
# Out:
# this utility.py is being used
# 2024-01-08 11:03:50.258499	开始加载历史数据
# 2024-01-08 11:03:54.880865	历史数据加载完成，数据量：39885
# 2024-01-08 11:03:54.949100	策略初始化完成
# 2024-01-08 11:03:54.949100	开始回放历史数据
# 2024-01-08 11:03:55.868524	历史数据回放结束
# 2024-01-08 11:03:55.868524	开始计算逐日盯市盈亏
# 2024-01-08 11:03:55.871524	逐日盯市盈亏计算完成
# 2024-01-08 11:03:55.871524	开始计算策略统计指标
# 2024-01-08 11:03:55.875524	------------------------------
# 2024-01-08 11:03:55.875524	首个交易日：	2023-01-17
# 2024-01-08 11:03:55.875524	最后交易日：	2023-06-29
# 2024-01-08 11:03:55.875524	总交易日：	107
# 2024-01-08 11:03:55.875524	盈利交易日：	37
# 2024-01-08 11:03:55.875524	亏损交易日：	17
# 2024-01-08 11:03:55.875524	起始资金：	1,000,000.00
# 2024-01-08 11:03:55.875524	结束资金：	1,033,726.80
# 2024-01-08 11:03:55.875524	总收益率：	3.37%
# 2024-01-08 11:03:55.875524	年化收益：	7.56%
# 2024-01-08 11:03:55.875524	最大回撤: 	-5,072.32
# 2024-01-08 11:03:55.875524	百分比最大回撤: -0.50%
# 2024-01-08 11:03:55.875524	最长回撤天数: 	1
# 2024-01-08 11:03:55.875524	总盈亏：	33,726.80
# 2024-01-08 11:03:55.875524	总手续费：	13,573.20
# 2024-01-08 11:03:55.875524	总滑点：	7,300.00
# 2024-01-08 11:03:55.875524	总成交金额：	67,866,000.00
# 2024-01-08 11:03:55.875524	总成交笔数：	73
# 2024-01-08 11:03:55.875524	日均盈亏：	315.20
# 2024-01-08 11:03:55.875524	日均手续费：	126.85
# 2024-01-08 11:03:55.875524	日均滑点：	68.22
# 2024-01-08 11:03:55.875524	日均成交金额：	634,261.68
# 2024-01-08 11:03:55.875524	日均成交笔数：	0.6822429906542056
# 2024-01-08 11:03:55.875524	日均收益率：	0.03%
# 2024-01-08 11:03:55.875524	收益标准差：	0.15%
# 2024-01-08 11:03:55.875524	Sharpe Ratio：	3.18
# 2024-01-08 11:03:55.875524	收益回撤比：	6.79

# %%
for trade in engine.trades.values():
    print(trade)
# Out:
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='1', tradeid='1', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=87.0, volume=10, datetime=datetime.datetime(2023, 2, 9, 21, 9, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='2', tradeid='2', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=102.0, volume=10, datetime=datetime.datetime(2023, 2, 10, 9, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='6', tradeid='3', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=105.0, volume=10, datetime=datetime.datetime(2023, 3, 10, 21, 27, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='12', tradeid='4', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=113.0, volume=10, datetime=datetime.datetime(2023, 3, 13, 9, 23, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='15', tradeid='5', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=122.0, volume=10, datetime=datetime.datetime(2023, 3, 17, 14, 10, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='16', tradeid='6', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=119.0, volume=10, datetime=datetime.datetime(2023, 3, 20, 13, 42, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='17', tradeid='7', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=93.0, volume=10, datetime=datetime.datetime(2023, 3, 27, 13, 34, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='18', tradeid='8', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=98.0, volume=10, datetime=datetime.datetime(2023, 3, 28, 14, 6, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='20', tradeid='9', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=91.0, volume=10, datetime=datetime.datetime(2023, 4, 6, 9, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='24', tradeid='10', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=80.0, volume=10, datetime=datetime.datetime(2023, 4, 11, 10, 2, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='26', tradeid='11', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=120.0, volume=10, datetime=datetime.datetime(2023, 4, 17, 9, 56, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='27', tradeid='12', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=107.0, volume=10, datetime=datetime.datetime(2023, 4, 17, 10, 54, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='28', tradeid='13', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=101.0, volume=10, datetime=datetime.datetime(2023, 4, 19, 14, 5, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='29', tradeid='14', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=108.0, volume=10, datetime=datetime.datetime(2023, 4, 20, 21, 15, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='30', tradeid='15', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=114.0, volume=10, datetime=datetime.datetime(2023, 4, 26, 9, 34, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='35', tradeid='16', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=97.0, volume=10, datetime=datetime.datetime(2023, 4, 26, 14, 43, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='37', tradeid='17', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=85.0, volume=10, datetime=datetime.datetime(2023, 5, 4, 9, 6, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='39', tradeid='18', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=100.0, volume=10, datetime=datetime.datetime(2023, 5, 4, 9, 30, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='40', tradeid='19', direction=<Direction.LONG: '多'>, offset=<Offset.NONE: ''>, price=77.0, volume=10, datetime=datetime.datetime(2023, 5, 5, 9, 15, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))
# TradeData(gateway_name='BACKTESTING', extra=None, symbol='SA-Spread', exchange=<Exchange.LOCAL: 'LOCAL'>, orderid='41', tradeid='20', direction=<Direction.SHORT: '空'>, offset=<Offset.NONE: ''>, price=77.0, volume=10, datetime=datetime.datetime(2023, 5, 8, 9, 58, tzinfo=zoneinfo.ZoneInfo(key='Asia/Shanghai')))

# %%
# Let's try to read the uploaded CSV file to check its contents and format
import pandas as pd

# Reading the dataset
file_path = 'D:/fut_data_1min_2023/AP301.csv'
data = pd.read_csv(file_path, encoding='GBK')

# Displaying the first few rows of the dataset
data.head()
# Out:
#   市场代码   合约代码                   时间       开       高       低       收   成交量  \
# 0   ZC  AP301  2023-01-03 09:01:00  8800.0  8800.0  8800.0  8800.0   1.0
# 1   ZC  AP301  2023-01-03 09:02:00  8880.0  8880.0  8661.0  8665.0  12.0
# 2   ZC  AP301  2023-01-03 09:03:00  8849.0  8849.0  8849.0  8849.0   2.0
# 3   ZC  AP301  2023-01-03 09:04:00  8850.0  8850.0  8850.0  8850.0   2.0
# 4   ZC  AP301  2023-01-03 09:05:00  8721.0  8850.0  8721.0  8850.0   4.0
#
#         成交额  持仓量
# 0    8800.0  214
# 1  106120.0  205
# 2   17710.0  204
# 3   17701.0  202
# 4   35267.0  200

# %%
setting = OptimizationSetting()
setting.set_target("sharpe_ratio")
setting.add_parameter("boll_window", 10, 1000, 100)
setting.add_parameter("boll_dev", 1, 5, 1)

engine.run_ga_optimization(setting)
# Out:
# 2024-01-08 11:00:28.389663	开始执行遗传算法优化
# 2024-01-08 11:00:28.390665	参数优化空间：50
# 2024-01-08 11:00:28.390665	每代族群总数：100
# 2024-01-08 11:00:28.390665	优良筛选个数：80
# 2024-01-08 11:00:28.390665	迭代次数：30
# 2024-01-08 11:00:28.390665	交叉概率：95%
# 2024-01-08 11:00:28.390665	突变概率：5%
# gen	nevals
# 0  	100
# 1  	100
# 2  	100
# 3  	100
# 4  	100
# 5  	100
# 6  	100
# 7  	100
# 8  	100
# 9  	100
# 10 	100
# 11 	100
# 12 	100
# 13 	100
# 14 	100
# 15 	100
# 16 	100
# 17 	100
# 18 	100
# 19 	100
# 20 	100
# 21 	100
# 22 	100
# 23 	100
# 24 	100
# 25 	100
# 26 	100
# 27 	100
# 28 	100
# 29 	100
# 30 	100
# 2024-01-08 11:02:01.997426	遗传算法优化完成，耗时93秒
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 510, 'boll_dev': 3}, 目标：3.1763558282468165
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 210, 'boll_dev': 4}, 目标：3.1090678867677846
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 810, 'boll_dev': 3}, 目标：3.068326517153602
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 910, 'boll_dev': 3}, 目标：3.011142482296955
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 310, 'boll_dev': 3}, 目标：2.5498882658480397
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 610, 'boll_dev': 3}, 目标：2.535693086566243
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 910, 'boll_dev': 4}, 目标：2.3872770991373575
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 710, 'boll_dev': 2}, 目标：2.3419726094720765
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 710, 'boll_dev': 4}, 目标：2.068986092645363
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 910, 'boll_dev': 2}, 目标：2.0661187056363004
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 810, 'boll_dev': 1}, 目标：2.0579276074711137
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 810, 'boll_dev': 4}, 目标：1.9592496962339891
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 810, 'boll_dev': 2}, 目标：1.7167019312646477
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 710, 'boll_dev': 1}, 目标：1.7092780759040316
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 910, 'boll_dev': 1}, 目标：1.6123556421616068
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 710, 'boll_dev': 3}, 目标：1.5889273034823324
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 410, 'boll_dev': 3}, 目标：1.4701407348203623
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 310, 'boll_dev': 4}, 目标：1.4295894994484042
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 610, 'boll_dev': 4}, 目标：1.3941154293635019
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 610, 'boll_dev': 2}, 目标：1.366618126052346
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 510, 'boll_dev': 2}, 目标：1.360397377540294
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 810, 'boll_dev': 5}, 目标：1.3237474254346284
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 310, 'boll_dev': 5}, 目标：1.248443836305263
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 110, 'boll_dev': 4}, 目标：1.2253181421583947
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 410, 'boll_dev': 4}, 目标：1.1419843911412264
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 610, 'boll_dev': 1}, 目标：1.0072608892693273
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 610, 'boll_dev': 5}, 目标：0.9797829064752701
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 510, 'boll_dev': 4}, 目标：0.9791045470284737
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 710, 'boll_dev': 5}, 目标：0.8690080175077616
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 310, 'boll_dev': 2}, 目标：0.7657792561615026
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 210, 'boll_dev': 5}, 目标：0.7024997694068145
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 210, 'boll_dev': 3}, 目标：0.687053346252429
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 410, 'boll_dev': 2}, 目标：0.5772471838806063
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 410, 'boll_dev': 5}, 目标：0.3913747652311733
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 910, 'boll_dev': 5}, 目标：0.3803431108533925
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 510, 'boll_dev': 1}, 目标：-0.005064420393940785
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 410, 'boll_dev': 1}, 目标：-0.28639701377121746
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 110, 'boll_dev': 3}, 目标：-0.5734218754609757
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 110, 'boll_dev': 5}, 目标：-0.5954906669138726
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 310, 'boll_dev': 1}, 目标：-0.6237588966427595
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 510, 'boll_dev': 5}, 目标：-0.8226916405022521
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 210, 'boll_dev': 2}, 目标：-0.9805419443676325
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 110, 'boll_dev': 2}, 目标：-1.423415069428368
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 210, 'boll_dev': 1}, 目标：-1.746142699838038
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 10, 'boll_dev': 5}, 目标：-1.9056253884788086
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 10, 'boll_dev': 4}, 目标：-1.9056253884788086
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 10, 'boll_dev': 3}, 目标：-1.9576172063706736
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 110, 'boll_dev': 1}, 目标：-5.611265259249166
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 10, 'boll_dev': 2}, 目标：-15.138867299348181
# 2024-01-08 11:02:02.066630	参数：{'boll_window': 10, 'boll_dev': 1}, 目标：-23.748758033431706
# [("{'boll_window': 510, 'boll_dev': 3}",
#   3.1763558282468165,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 37,
#    'loss_days': 17,
#    'capital': 1000000,
#    'end_balance': 1033726.8,
#    'max_drawdown': -5072.320000000065,
#    'max_ddpercent': -0.4966260928903281,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 33726.8,
#    'daily_net_pnl': 315.20373831775703,
#    'total_commission': 13573.199999999999,
#    'daily_commission': 126.85233644859812,
#    'total_slippage': 7300.0,
#    'daily_slippage': 68.22429906542057,
#    'total_turnover': 67866000.0,
#    'daily_turnover': 634261.6822429907,
#    'total_trade_count': 73,
#    'daily_trade_count': 0.6822429906542056,
#    'total_return': 3.3726799999999946,
#    'annual_return': 7.564889719626157,
#    'daily_return': 0.031000490224713358,
#    'return_std': 0.15119764769030927,
#    'sharpe_ratio': 3.1763558282468165,
#    'return_drawdown_ratio': 6.791185659157053}),
#  ("{'boll_window': 210, 'boll_dev': 4}",
#   3.1090678867677846,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 21,
#    'loss_days': 8,
#    'capital': 1000000,
#    'end_balance': 1019444.44,
#    'max_drawdown': -4684.0800000000745,
#    'max_ddpercent': -0.46296043712840496,
#    'max_drawdown_duration': 3,
#    'total_net_pnl': 19444.44,
#    'daily_net_pnl': 181.723738317757,
#    'total_commission': 8555.56,
#    'daily_commission': 79.95850467289719,
#    'total_slippage': 4600.0,
#    'daily_slippage': 42.99065420560748,
#    'total_turnover': 42777800.0,
#    'daily_turnover': 399792.523364486,
#    'total_trade_count': 46,
#    'daily_trade_count': 0.42990654205607476,
#    'total_return': 1.9444440000000007,
#    'annual_return': 4.36136971962617,
#    'daily_return': 0.017997955368917247,
#    'return_std': 0.08968061676140193,
#    'sharpe_ratio': 3.1090678867677846,
#    'return_drawdown_ratio': 4.200021954490891}),
#  ("{'boll_window': 810, 'boll_dev': 3}",
#   3.068326517153602,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 34,
#    'loss_days': 14,
#    'capital': 1000000,
#    'end_balance': 1029170.64,
#    'max_drawdown': -5872.959999999963,
#    'max_ddpercent': -0.5769977669356396,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 29170.64,
#    'daily_net_pnl': 272.62280373831777,
#    'total_commission': 9629.36,
#    'daily_commission': 89.99401869158879,
#    'total_slippage': 5200.0,
#    'daily_slippage': 48.598130841121495,
#    'total_turnover': 48146800.0,
#    'daily_turnover': 449970.09345794393,
#    'total_trade_count': 52,
#    'daily_trade_count': 0.48598130841121495,
#    'total_return': 2.9170640000000025,
#    'annual_return': 6.542947289719631,
#    'daily_return': 0.026872218698391598,
#    'return_std': 0.13567741883098178,
#    'sharpe_ratio': 3.068326517153602,
#    'return_drawdown_ratio': 5.055589756425144}),
#  ("{'boll_window': 910, 'boll_dev': 3}",
#   3.011142482296955,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 32,
#    'loss_days': 16,
#    'capital': 1000000,
#    'end_balance': 1029565.6,
#    'max_drawdown': -5872.960000000079,
#    'max_ddpercent': -0.578024259665273,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 29565.6,
#    'daily_net_pnl': 276.3140186915888,
#    'total_commission': 8834.400000000001,
#    'daily_commission': 82.56448598130842,
#    'total_slippage': 4800.0,
#    'daily_slippage': 44.85981308411215,
#    'total_turnover': 44172000.0,
#    'daily_turnover': 412822.42990654206,
#    'total_trade_count': 48,
#    'daily_trade_count': 0.4485981308411215,
#    'total_return': 2.956559999999997,
#    'annual_return': 6.631536448598124,
#    'daily_return': 0.02723080907309186,
#    'return_std': 0.14009894339292556,
#    'sharpe_ratio': 3.011142482296955,
#    'return_drawdown_ratio': 5.114941026371636}),
#  ("{'boll_window': 310, 'boll_dev': 3}",
#   2.5498882658480397,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 46,
#    'loss_days': 18,
#    'capital': 1000000,
#    'end_balance': 1024051.88,
#    'max_drawdown': -8895.0,
#    'max_ddpercent': -0.8614192485937222,
#    'max_drawdown_duration': 12,
#    'total_net_pnl': 24051.88,
#    'daily_net_pnl': 224.78392523364488,
#    'total_commission': 20048.12,
#    'daily_commission': 187.36560747663552,
#    'total_slippage': 10700.0,
#    'daily_slippage': 100.0,
#    'total_turnover': 100240600.0,
#    'daily_turnover': 936828.0373831776,
#    'total_trade_count': 107,
#    'daily_trade_count': 1.0,
#    'total_return': 2.4051880000000025,
#    'annual_return': 5.394814205607482,
#    'daily_return': 0.022212326538724514,
#    'return_std': 0.13495174971737825,
#    'sharpe_ratio': 2.5498882658480397,
#    'return_drawdown_ratio': 2.792122423461633}),
#  ("{'boll_window': 610, 'boll_dev': 3}",
#   2.535693086566243,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 34,
#    'loss_days': 16,
#    'capital': 1000000,
#    'end_balance': 1023842.68,
#    'max_drawdown': -5072.319999999949,
#    'max_ddpercent': -0.50023258558802,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 23842.68,
#    'daily_net_pnl': 222.82878504672897,
#    'total_commission': 11257.32,
#    'daily_commission': 105.20859813084112,
#    'total_slippage': 6100.0,
#    'daily_slippage': 57.00934579439252,
#    'total_turnover': 56286600.0,
#    'daily_turnover': 526042.9906542056,
#    'total_trade_count': 61,
#    'daily_trade_count': 0.5700934579439252,
#    'total_return': 2.3842680000000005,
#    'annual_return': 5.3478908411214965,
#    'daily_return': 0.022021385048678135,
#    'return_std': 0.13454066346719654,
#    'sharpe_ratio': 2.535693086566243,
#    'return_drawdown_ratio': 4.766318845857092}),
#  ("{'boll_window': 910, 'boll_dev': 4}",
#   2.3872770991373575,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 12,
#    'loss_days': 3,
#    'capital': 1000000,
#    'end_balance': 1015370.92,
#    'max_drawdown': -3671.8000000000466,
#    'max_ddpercent': -0.36390312513875517,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 15370.919999999998,
#    'daily_net_pnl': 143.65345794392522,
#    'total_commission': 2629.08,
#    'daily_commission': 24.570841121495327,
#    'total_slippage': 1400.0,
#    'daily_slippage': 13.08411214953271,
#    'total_turnover': 13145400.0,
#    'daily_turnover': 122854.20560747663,
#    'total_trade_count': 14,
#    'daily_trade_count': 0.1308411214953271,
#    'total_return': 1.5370920000000066,
#    'annual_return': 3.4476829906542203,
#    'daily_return': 0.014256059963587453,
#    'return_std': 0.09251290156716187,
#    'sharpe_ratio': 2.3872770991373575,
#    'return_drawdown_ratio': 4.223904368542914}),
#  ("{'boll_window': 710, 'boll_dev': 2}",
#   2.3419726094720765,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 59,
#    'loss_days': 39,
#    'capital': 1000000,
#    'end_balance': 1029769.4400000001,
#    'max_drawdown': -8526.280000000028,
#    'max_ddpercent': -0.8378717051624949,
#    'max_drawdown_duration': 15,
#    'total_net_pnl': 29769.439999999995,
#    'daily_net_pnl': 278.2190654205607,
#    'total_commission': 25730.559999999998,
#    'daily_commission': 240.47252336448597,
#    'total_slippage': 13500.0,
#    'daily_slippage': 126.16822429906541,
#    'total_turnover': 128652800.0,
#    'daily_turnover': 1202362.61682243,
#    'total_trade_count': 135,
#    'daily_trade_count': 1.2616822429906542,
#    'total_return': 2.9769440000000147,
#    'annual_return': 6.6772575700934915,
#    'daily_return': 0.027415824789154355,
#    'return_std': 0.18135315913002148,
#    'sharpe_ratio': 2.3419726094720765,
#    'return_drawdown_ratio': 3.5529830899620523}),
#  ("{'boll_window': 710, 'boll_dev': 4}",
#   2.068986092645363,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 14,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 1012952.8,
#    'max_drawdown': -4798.679999999935,
#    'max_ddpercent': -0.4770097195993765,
#    'max_drawdown_duration': 13,
#    'total_net_pnl': 12952.8,
#    'daily_net_pnl': 121.05420560747663,
#    'total_commission': 3847.2,
#    'daily_commission': 35.955140186915884,
#    'total_slippage': 2000.0,
#    'daily_slippage': 18.69158878504673,
#    'total_turnover': 19236000.0,
#    'daily_turnover': 179775.70093457945,
#    'total_trade_count': 20,
#    'daily_trade_count': 0.18691588785046728,
#    'total_return': 1.2952800000000098,
#    'annual_return': 2.905300934579461,
#    'daily_return': 0.012027691501464476,
#    'return_std': 0.09005966554165142,
#    'sharpe_ratio': 2.068986092645363,
#    'return_drawdown_ratio': 2.7154163673810867}),
#  ("{'boll_window': 910, 'boll_dev': 2}",
#   2.0661187056363004,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 56,
#    'loss_days': 35,
#    'capital': 1000000,
#    'end_balance': 1024491.56,
#    'max_drawdown': -8010.239999999991,
#    'max_ddpercent': -0.7961830161777147,
#    'max_drawdown_duration': 57,
#    'total_net_pnl': 24491.559999999998,
#    'daily_net_pnl': 228.89308411214952,
#    'total_commission': 18308.440000000002,
#    'daily_commission': 171.10691588785048,
#    'total_slippage': 9800.0,
#    'daily_slippage': 91.58878504672897,
#    'total_turnover': 91542200.0,
#    'daily_turnover': 855534.5794392524,
#    'total_trade_count': 98,
#    'daily_trade_count': 0.9158878504672897,
#    'total_return': 2.449155999999997,
#    'annual_return': 5.493434018691581,
#    'daily_return': 0.022613505138247444,
#    'return_std': 0.1695579804991616,
#    'sharpe_ratio': 2.0661187056363004,
#    'return_drawdown_ratio': 3.076121884334851}),
#  ("{'boll_window': 810, 'boll_dev': 1}",
#   2.0579276074711137,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 60,
#    'loss_days': 46,
#    'capital': 1000000,
#    'end_balance': 1029202.24,
#    'max_drawdown': -11368.399999999907,
#    'max_ddpercent': -1.1108680819821413,
#    'max_drawdown_duration': 62,
#    'total_net_pnl': 29202.23999999999,
#    'daily_net_pnl': 272.9181308411214,
#    'total_commission': 54097.76000000001,
#    'daily_commission': 505.58654205607485,
#    'total_slippage': 27700.0,
#    'daily_slippage': 258.8785046728972,
#    'total_turnover': 270488800.0,
#    'daily_turnover': 2527932.7102803737,
#    'total_trade_count': 277,
#    'daily_trade_count': 2.588785046728972,
#    'total_return': 2.9202240000000046,
#    'annual_return': 6.5500351401869255,
#    'daily_return': 0.026913661648444484,
#    'return_std': 0.20260414014850106,
#    'sharpe_ratio': 2.0579276074711137,
#    'return_drawdown_ratio': 2.6287765823547637}),
#  ("{'boll_window': 810, 'boll_dev': 4}",
#   1.9592496962339891,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 11,
#    'loss_days': 4,
#    'capital': 1000000,
#    'end_balance': 1011868.0,
#    'max_drawdown': -3872.079999999958,
#    'max_ddpercent': -0.38321684257064365,
#    'max_drawdown_duration': 1,
#    'total_net_pnl': 11868.0,
#    'daily_net_pnl': 110.91588785046729,
#    'total_commission': 2732.0,
#    'daily_commission': 25.53271028037383,
#    'total_slippage': 1400.0,
#    'daily_slippage': 13.08411214953271,
#    'total_turnover': 13660000.0,
#    'daily_turnover': 127663.55140186916,
#    'total_trade_count': 14,
#    'daily_trade_count': 0.1308411214953271,
#    'total_return': 1.186799999999999,
#    'annual_return': 2.661981308411213,
#    'daily_return': 0.011026287453560173,
#    'return_std': 0.08718567676232364,
#    'sharpe_ratio': 1.9592496962339891,
#    'return_drawdown_ratio': 3.09694112617511}),
#  ("{'boll_window': 810, 'boll_dev': 2}",
#   1.7167019312646477,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 57,
#    'loss_days': 39,
#    'capital': 1000000,
#    'end_balance': 1035429.44,
#    'max_drawdown': -21938.719999999972,
#    'max_ddpercent': -2.1329698245134234,
#    'max_drawdown_duration': 25,
#    'total_net_pnl': 35429.439999999995,
#    'daily_net_pnl': 331.11626168224296,
#    'total_commission': 23370.56,
#    'daily_commission': 218.41644859813084,
#    'total_slippage': 12400.0,
#    'daily_slippage': 115.88785046728972,
#    'total_turnover': 116852800.0,
#    'daily_turnover': 1092082.2429906542,
#    'total_trade_count': 124,
#    'daily_trade_count': 1.158878504672897,
#    'total_return': 3.5429439999999923,
#    'annual_return': 7.946790280373814,
#    'daily_return': 0.03253855938047795,
#    'return_std': 0.2936358287832431,
#    'sharpe_ratio': 1.7167019312646477,
#    'return_drawdown_ratio': 1.6610380321757316}),
#  ("{'boll_window': 710, 'boll_dev': 1}",
#   1.7092780759040316,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 56,
#    'loss_days': 50,
#    'capital': 1000000,
#    'end_balance': 1027837.96,
#    'max_drawdown': -15079.96000000008,
#    'max_ddpercent': -1.4670973172984305,
#    'max_drawdown_duration': 58,
#    'total_net_pnl': 27837.960000000003,
#    'daily_net_pnl': 260.1678504672897,
#    'total_commission': 58862.04,
#    'daily_commission': 550.112523364486,
#    'total_slippage': 30100.0,
#    'daily_slippage': 281.30841121495325,
#    'total_turnover': 294310200.0,
#    'daily_turnover': 2750562.61682243,
#    'total_trade_count': 301,
#    'daily_trade_count': 2.8130841121495327,
#    'total_return': 2.783796000000005,
#    'annual_return': 6.244028411214965,
#    'daily_return': 0.02364718870003219,
#    'return_std': 0.21432479433496462,
#    'sharpe_ratio': 1.7092780759040316,
#    'return_drawdown_ratio': 1.8974855772527717}),
#  ("{'boll_window': 910, 'boll_dev': 1}",
#   1.6123556421616068,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 56,
#    'loss_days': 50,
#    'capital': 1000000,
#    'end_balance': 1023096.48,
#    'max_drawdown': -16248.359999999986,
#    'max_ddpercent': -1.597816161752998,
#    'max_drawdown_duration': 62,
#    'total_net_pnl': 23096.48,
#    'daily_net_pnl': 215.85495327102802,
#    'total_commission': 44003.520000000004,
#    'daily_commission': 411.24785046728977,
#    'total_slippage': 22700.0,
#    'daily_slippage': 212.14953271028037,
#    'total_turnover': 220017600.0,
#    'daily_turnover': 2056239.2523364485,
#    'total_trade_count': 227,
#    'daily_trade_count': 2.121495327102804,
#    'total_return': 2.3096479999999975,
#    'annual_return': 5.1805188785046665,
#    'daily_return': 0.020877752996760254,
#    'return_std': 0.20059889406106576,
#    'sharpe_ratio': 1.6123556421616068,
#    'return_drawdown_ratio': 1.4455029654137643}),
#  ("{'boll_window': 710, 'boll_dev': 3}",
#   1.5889273034823324,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 54,
#    'loss_days': 44,
#    'capital': 1000000,
#    'end_balance': 1030647.4,
#    'max_drawdown': -23063.20000000007,
#    'max_ddpercent': -2.2494059797807893,
#    'max_drawdown_duration': 25,
#    'total_net_pnl': 30647.4,
#    'daily_net_pnl': 286.4242990654206,
#    'total_commission': 11152.600000000002,
#    'daily_commission': 104.2299065420561,
#    'total_slippage': 6000.0,
#    'daily_slippage': 56.074766355140184,
#    'total_turnover': 55763000.0,
#    'daily_turnover': 521149.5327102804,
#    'total_trade_count': 60,
#    'daily_trade_count': 0.5607476635514018,
#    'total_return': 3.0647400000000102,
#    'annual_return': 6.874183177570116,
#    'daily_return': 0.02821228829907917,
#    'return_std': 0.27506789643872703,
#    'sharpe_ratio': 1.5889273034823324,
#    'return_drawdown_ratio': 1.3624663700319128}),
#  ("{'boll_window': 410, 'boll_dev': 3}",
#   1.4701407348203623,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 59,
#    'loss_days': 44,
#    'capital': 1000000,
#    'end_balance': 1028842.24,
#    'max_drawdown': -24160.52000000002,
#    'max_ddpercent': -2.332788976125425,
#    'max_drawdown_duration': 25,
#    'total_net_pnl': 28842.24,
#    'daily_net_pnl': 269.5536448598131,
#    'total_commission': 15157.760000000002,
#    'daily_commission': 141.66130841121497,
#    'total_slippage': 8000.0,
#    'daily_slippage': 74.76635514018692,
#    'total_turnover': 75788800.0,
#    'daily_turnover': 708306.5420560747,
#    'total_trade_count': 80,
#    'daily_trade_count': 0.7476635514018691,
#    'total_return': 2.884223999999991,
#    'annual_return': 6.469287476635493,
#    'daily_return': 0.02657395439359706,
#    'return_std': 0.2800289261336678,
#    'sharpe_ratio': 1.4701407348203623,
#    'return_drawdown_ratio': 1.236384443478662}),
#  ("{'boll_window': 310, 'boll_dev': 4}",
#   1.4295894994484042,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 16,
#    'loss_days': 7,
#    'capital': 1000000,
#    'end_balance': 1010072.16,
#    'max_drawdown': -9200.600000000093,
#    'max_ddpercent': -0.9029721194918605,
#    'max_drawdown_duration': 35,
#    'total_net_pnl': 10072.160000000002,
#    'daily_net_pnl': 94.13233644859815,
#    'total_commission': 7427.839999999999,
#    'daily_commission': 69.41906542056074,
#    'total_slippage': 3900.0,
#    'daily_slippage': 36.44859813084112,
#    'total_turnover': 37139200.0,
#    'daily_turnover': 347095.32710280374,
#    'total_trade_count': 39,
#    'daily_trade_count': 0.3644859813084112,
#    'total_return': 1.0072159999999997,
#    'annual_return': 2.2591760747663545,
#    'daily_return': 0.00936614378094499,
#    'return_std': 0.10149744075702992,
#    'sharpe_ratio': 1.4295894994484042,
#    'return_drawdown_ratio': 1.115445292559865}),
#  ("{'boll_window': 610, 'boll_dev': 4}",
#   1.3941154293635019,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 13,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 1007417.56,
#    'max_drawdown': -4798.599999999977,
#    'max_ddpercent': -0.47739243488685706,
#    'max_drawdown_duration': 13,
#    'total_net_pnl': 7417.5599999999995,
#    'daily_net_pnl': 69.3229906542056,
#    'total_commission': 3982.4400000000005,
#    'daily_commission': 37.21906542056075,
#    'total_slippage': 2000.0,
#    'daily_slippage': 18.69158878504673,
#    'total_turnover': 19912200.0,
#    'daily_turnover': 186095.32710280374,
#    'total_trade_count': 20,
#    'daily_trade_count': 0.18691588785046728,
#    'total_return': 0.7417560000000156,
#    'annual_return': 1.6637517757009697,
#    'daily_return': 0.0069067151289879,
#    'return_std': 0.07675000823649662,
#    'sharpe_ratio': 1.3941154293635019,
#    'return_drawdown_ratio': 1.5537657193411816}),
#  ("{'boll_window': 610, 'boll_dev': 2}",
#   1.366618126052346,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 59,
#    'loss_days': 42,
#    'capital': 1000000,
#    'end_balance': 1018352.36,
#    'max_drawdown': -10028.759999999893,
#    'max_ddpercent': -0.9831295288123442,
#    'max_drawdown_duration': 17,
#    'total_net_pnl': 18352.359999999997,
#    'daily_net_pnl': 171.51738317757005,
#    'total_commission': 28947.640000000003,
#    'daily_commission': 270.53869158878507,
#    'total_slippage': 15100.0,
#    'daily_slippage': 141.1214953271028,
#    'total_turnover': 144738200.0,
#    'daily_turnover': 1352693.4579439252,
#    'total_trade_count': 151,
#    'daily_trade_count': 1.411214953271028,
#    'total_return': 1.8352359999999956,
#    'annual_return': 4.116417196261673,
#    'daily_return': 0.0160748355869982,
#    'return_std': 0.18222375171125654,
#    'sharpe_ratio': 1.366618126052346,
#    'return_drawdown_ratio': 1.8667285909080837}),
#  ("{'boll_window': 510, 'boll_dev': 2}",
#   1.360397377540294,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 60,
#    'loss_days': 42,
#    'capital': 1000000,
#    'end_balance': 1017952.88,
#    'max_drawdown': -12102.119999999995,
#    'max_ddpercent': -1.1813279642369825,
#    'max_drawdown_duration': 17,
#    'total_net_pnl': 17952.88,
#    'daily_net_pnl': 167.78392523364488,
#    'total_commission': 37547.12,
#    'daily_commission': 350.90766355140187,
#    'total_slippage': 19500.0,
#    'daily_slippage': 182.2429906542056,
#    'total_turnover': 187735600.0,
#    'daily_turnover': 1754538.3177570093,
#    'total_trade_count': 195,
#    'daily_trade_count': 1.8224299065420562,
#    'total_return': 1.7952879999999949,
#    'annual_return': 4.026814205607465,
#    'daily_return': 0.016629560953389647,
#    'return_std': 0.18937411580040064,
#    'sharpe_ratio': 1.360397377540294,
#    'return_drawdown_ratio': 1.519720225330963}),
#  ("{'boll_window': 810, 'boll_dev': 5}",
#   1.3237474254346284,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 4,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1006627.12,
#    'max_drawdown': -3671.79999999993,
#    'max_ddpercent': -0.3653627877950809,
#    'max_drawdown_duration': 15,
#    'total_net_pnl': 6627.119999999999,
#    'daily_net_pnl': 61.93570093457943,
#    'total_commission': 1172.8799999999999,
#    'daily_commission': 10.961495327102803,
#    'total_slippage': 600.0,
#    'daily_slippage': 5.607476635514018,
#    'total_turnover': 5864400.0,
#    'daily_turnover': 54807.47663551402,
#    'total_trade_count': 6,
#    'daily_trade_count': 0.056074766355140186,
#    'total_return': 0.6627120000000097,
#    'annual_return': 1.4864568224299284,
#    'daily_return': 0.006173137550271007,
#    'return_std': 0.07224477560195398,
#    'sharpe_ratio': 1.3237474254346284,
#    'return_drawdown_ratio': 1.8138464620313262}),
#  ("{'boll_window': 310, 'boll_dev': 5}",
#   1.248443836305263,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 5,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1004834.96,
#    'max_drawdown': -3700.5200000000186,
#    'max_ddpercent': -0.3680168520872851,
#    'max_drawdown_duration': 13,
#    'total_net_pnl': 4834.959999999999,
#    'daily_net_pnl': 45.18654205607476,
#    'total_commission': 2365.04,
#    'daily_commission': 22.103177570093457,
#    'total_slippage': 1200.0,
#    'daily_slippage': 11.214953271028037,
#    'total_turnover': 11825200.0,
#    'daily_turnover': 110515.88785046729,
#    'total_trade_count': 12,
#    'daily_trade_count': 0.11214953271028037,
#    'total_return': 0.4834959999999944,
#    'annual_return': 1.0844770093457816,
#    'daily_return': 0.004507765532865031,
#    'return_std': 0.05593684018357461,
#    'sharpe_ratio': 1.248443836305263,
#    'return_drawdown_ratio': 1.313787662868548}),
#  ("{'boll_window': 110, 'boll_dev': 4}",
#   1.2253181421583947,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 16,
#    'loss_days': 7,
#    'capital': 1000000,
#    'end_balance': 1005357.08,
#    'max_drawdown': -4273.599999999977,
#    'max_ddpercent': -0.42530788943348113,
#    'max_drawdown_duration': 8,
#    'total_net_pnl': 5357.079999999998,
#    'daily_net_pnl': 50.06616822429905,
#    'total_commission': 7242.920000000001,
#    'daily_commission': 67.69084112149534,
#    'total_slippage': 4000.0,
#    'daily_slippage': 37.38317757009346,
#    'total_turnover': 36214600.0,
#    'daily_turnover': 338454.20560747664,
#    'total_trade_count': 40,
#    'daily_trade_count': 0.37383177570093457,
#    'total_return': 0.5357080000000014,
#    'annual_return': 1.2015880373831807,
#    'daily_return': 0.004993254101206155,
#    'return_std': 0.06313067378007836,
#    'sharpe_ratio': 1.2253181421583947,
#    'return_drawdown_ratio': 1.259576916651077}),
#  ("{'boll_window': 410, 'boll_dev': 4}",
#   1.1419843911412264,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 52,
#    'loss_days': 49,
#    'capital': 1000000,
#    'end_balance': 1020954.36,
#    'max_drawdown': -22669.160000000033,
#    'max_ddpercent': -2.2025497435192727,
#    'max_drawdown_duration': 25,
#    'total_net_pnl': 20954.359999999997,
#    'daily_net_pnl': 195.83514018691585,
#    'total_commission': 7345.64,
#    'daily_commission': 68.65084112149533,
#    'total_slippage': 3700.0,
#    'daily_slippage': 34.57943925233645,
#    'total_turnover': 36728200.0,
#    'daily_turnover': 343254.20560747664,
#    'total_trade_count': 36,
#    'daily_trade_count': 0.3364485981308411,
#    'total_return': 2.095435999999995,
#    'annual_return': 4.70004336448597,
#    'daily_return': 0.01938115599078067,
#    'return_std': 0.26292091193130435,
#    'sharpe_ratio': 1.1419843911412264,
#    'return_drawdown_ratio': 0.951368297658454}),
#  ("{'boll_window': 610, 'boll_dev': 1}",
#   1.0072608892693273,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 56,
#    'loss_days': 40,
#    'capital': 1000000,
#    'end_balance': 1024964.68,
#    'max_drawdown': -26340.280000000028,
#    'max_ddpercent': -2.541059182472198,
#    'max_drawdown_duration': 26,
#    'total_net_pnl': 24964.68,
#    'daily_net_pnl': 233.3147663551402,
#    'total_commission': 70835.32,
#    'daily_commission': 662.0123364485981,
#    'total_slippage': 36400.0,
#    'daily_slippage': 340.1869158878505,
#    'total_turnover': 354176600.0,
#    'daily_turnover': 3310061.6822429905,
#    'total_trade_count': 363,
#    'daily_trade_count': 3.392523364485981,
#    'total_return': 2.4964680000000072,
#    'annual_return': 5.59955439252338,
#    'daily_return': 0.021144432382192855,
#    'return_std': 0.325206847019134,
#    'sharpe_ratio': 1.0072608892693273,
#    'return_drawdown_ratio': 0.9824517339935357}),
#  ("{'boll_window': 610, 'boll_dev': 5}",
#   0.9797829064752701,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 4,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1003831.12,
#    'max_drawdown': -3671.8000000000466,
#    'max_ddpercent': -0.36543552772999055,
#    'max_drawdown_duration': 15,
#    'total_net_pnl': 3831.1199999999994,
#    'daily_net_pnl': 35.80485981308411,
#    'total_commission': 1168.88,
#    'daily_commission': 10.92411214953271,
#    'total_slippage': 600.0,
#    'daily_slippage': 5.607476635514018,
#    'total_turnover': 5844400.0,
#    'daily_turnover': 54620.56074766355,
#    'total_trade_count': 6,
#    'daily_trade_count': 0.056074766355140186,
#    'total_return': 0.38311200000000767,
#    'annual_return': 0.8593166355140359,
#    'daily_return': 0.0035736448129063837,
#    'return_std': 0.05650503495897144,
#    'sharpe_ratio': 0.9797829064752701,
#    'return_drawdown_ratio': 1.0483709736155642}),
#  ("{'boll_window': 510, 'boll_dev': 4}",
#   0.9791045470284737,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 12,
#    'loss_days': 7,
#    'capital': 1000000,
#    'end_balance': 1005631.92,
#    'max_drawdown': -5233.959999999963,
#    'max_ddpercent': -0.5210948659159064,
#    'max_drawdown_duration': 23,
#    'total_net_pnl': 5631.919999999999,
#    'daily_net_pnl': 52.63476635514018,
#    'total_commission': 3968.08,
#    'daily_commission': 37.08485981308411,
#    'total_slippage': 2000.0,
#    'daily_slippage': 18.69158878504673,
#    'total_turnover': 19840400.0,
#    'daily_turnover': 185424.29906542055,
#    'total_trade_count': 20,
#    'daily_trade_count': 0.18691588785046728,
#    'total_return': 0.5631920000000123,
#    'annual_return': 1.2632343925233922,
#    'daily_return': 0.005248710311741135,
#    'return_std': 0.08304799600057167,
#    'sharpe_ratio': 0.9791045470284737,
#    'return_drawdown_ratio': 1.0807859313872026}),
#  ("{'boll_window': 710, 'boll_dev': 5}",
#   0.8690080175077616,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 4,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1003431.76,
#    'max_drawdown': -3671.8000000000466,
#    'max_ddpercent': -0.3657261944897645,
#    'max_drawdown_duration': 15,
#    'total_net_pnl': 3431.7599999999998,
#    'daily_net_pnl': 32.07252336448598,
#    'total_commission': 1168.24,
#    'daily_commission': 10.918130841121496,
#    'total_slippage': 600.0,
#    'daily_slippage': 5.607476635514018,
#    'total_turnover': 5841200.0,
#    'daily_turnover': 54590.654205607476,
#    'total_trade_count': 6,
#    'daily_trade_count': 0.056074766355140186,
#    'total_return': 0.3431760000000006,
#    'annual_return': 0.7697405607476648,
#    'daily_return': 0.0032017616345710854,
#    'return_std': 0.05707827425934604,
#    'sharpe_ratio': 0.8690080175077616,
#    'return_drawdown_ratio': 0.9383413197372303}),
#  ("{'boll_window': 310, 'boll_dev': 2}",
#   0.7657792561615026,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 59,
#    'loss_days': 47,
#    'capital': 1000000,
#    'end_balance': 1009494.8,
#    'max_drawdown': -10792.55999999994,
#    'max_ddpercent': -1.057796109519571,
#    'max_drawdown_duration': 51,
#    'total_net_pnl': 9494.799999999996,
#    'daily_net_pnl': 88.7364485981308,
#    'total_commission': 55005.2,
#    'daily_commission': 514.0672897196262,
#    'total_slippage': 28900.0,
#    'daily_slippage': 270.0934579439252,
#    'total_turnover': 275026000.0,
#    'daily_turnover': 2570336.448598131,
#    'total_trade_count': 289,
#    'daily_trade_count': 2.7009345794392523,
#    'total_return': 0.9494800000000136,
#    'annual_return': 2.129674766355171,
#    'daily_return': 0.008469273766005907,
#    'return_std': 0.17133583071774647,
#    'sharpe_ratio': 0.7657792561615026,
#    'return_drawdown_ratio': 0.8976020912302729}),
#  ("{'boll_window': 210, 'boll_dev': 5}",
#   0.7024997694068145,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 6,
#    'loss_days': 2,
#    'capital': 1000000,
#    'end_balance': 1002368.92,
#    'max_drawdown': -3700.5200000000186,
#    'max_ddpercent': -0.36903199556426225,
#    'max_drawdown_duration': 2,
#    'total_net_pnl': 2368.92,
#    'daily_net_pnl': 22.139439252336448,
#    'total_commission': 2231.0800000000004,
#    'daily_commission': 20.851214953271032,
#    'total_slippage': 1200.0,
#    'daily_slippage': 11.214953271028037,
#    'total_turnover': 11155400.0,
#    'daily_turnover': 104256.07476635514,
#    'total_trade_count': 12,
#    'daily_trade_count': 0.11214953271028037,
#    'total_return': 0.23689200000001076,
#    'annual_return': 0.5313465420560989,
#    'daily_return': 0.0022113257312581474,
#    'return_std': 0.048765440805394036,
#    'sharpe_ratio': 0.7024997694068145,
#    'return_drawdown_ratio': 0.6419280789943295}),
#  ("{'boll_window': 210, 'boll_dev': 3}",
#   0.687053346252429,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 59,
#    'loss_days': 44,
#    'capital': 1000000,
#    'end_balance': 1014003.96,
#    'max_drawdown': -18298.280000000028,
#    'max_ddpercent': -1.7725700178660881,
#    'max_drawdown_duration': 14,
#    'total_net_pnl': 14003.959999999995,
#    'daily_net_pnl': 130.87813084112145,
#    'total_commission': 27396.04,
#    'daily_commission': 256.0377570093458,
#    'total_slippage': 14800.0,
#    'daily_slippage': 138.3177570093458,
#    'total_turnover': 136980200.0,
#    'daily_turnover': 1280188.785046729,
#    'total_trade_count': 147,
#    'daily_trade_count': 1.3738317757009346,
#    'total_return': 1.4003959999999926,
#    'annual_return': 3.1410751401868993,
#    'daily_return': 0.012997019146550513,
#    'return_std': 0.29306160273868903,
#    'sharpe_ratio': 0.687053346252429,
#    'return_drawdown_ratio': 0.790037056863831}),
#  ("{'boll_window': 410, 'boll_dev': 2}",
#   0.5772471838806063,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 61,
#    'loss_days': 44,
#    'capital': 1000000,
#    'end_balance': 1008244.76,
#    'max_drawdown': -16940.400000000023,
#    'max_ddpercent': -1.6542070902758614,
#    'max_drawdown_duration': 41,
#    'total_net_pnl': 8244.759999999997,
#    'daily_net_pnl': 77.0538317757009,
#    'total_commission': 42455.240000000005,
#    'daily_commission': 396.77794392523367,
#    'total_slippage': 22100.0,
#    'daily_slippage': 206.54205607476635,
#    'total_turnover': 212276200.0,
#    'daily_turnover': 1983889.7196261683,
#    'total_trade_count': 221,
#    'daily_trade_count': 2.0654205607476634,
#    'total_return': 0.8244759999999962,
#    'annual_return': 1.849291962616814,
#    'daily_return': 0.006752377389630541,
#    'return_std': 0.18121765446502835,
#    'sharpe_ratio': 0.5772471838806063,
#    'return_drawdown_ratio': 0.49841159843082505}),
#  ("{'boll_window': 410, 'boll_dev': 5}",
#   0.3913747652311733,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 48,
#    'loss_days': 51,
#    'capital': 1000000,
#    'end_balance': 1007277.52,
#    'max_drawdown': -24800.0,
#    'max_ddpercent': -2.4369212754154184,
#    'max_drawdown_duration': 25,
#    'total_net_pnl': 7277.519999999999,
#    'daily_net_pnl': 68.01420560747663,
#    'total_commission': 2222.48,
#    'daily_commission': 20.770841121495327,
#    'total_slippage': 1100.0,
#    'daily_slippage': 10.280373831775702,
#    'total_turnover': 11112400.0,
#    'daily_turnover': 103854.20560747663,
#    'total_trade_count': 10,
#    'daily_trade_count': 0.09345794392523364,
#    'total_return': 0.7277519999999926,
#    'annual_return': 1.6323409345794229,
#    'daily_return': 0.00677679124503868,
#    'return_std': 0.2682482568057864,
#    'sharpe_ratio': 0.3913747652311733,
#    'return_drawdown_ratio': 0.29863582682864215}),
#  ("{'boll_window': 910, 'boll_dev': 5}",
#   0.3803431108533925,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 1,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 1001653.4,
#    'max_drawdown': -3671.8000000000466,
#    'max_ddpercent': -0.36718000000000467,
#    'max_drawdown_duration': 108,
#    'total_net_pnl': 1653.3999999999996,
#    'daily_net_pnl': 15.452336448598128,
#    'total_commission': 346.6,
#    'daily_commission': 3.2392523364485983,
#    'total_slippage': 200.0,
#    'daily_slippage': 1.8691588785046729,
#    'total_turnover': 1733000.0,
#    'daily_turnover': 16196.26168224299,
#    'total_trade_count': 2,
#    'daily_trade_count': 0.018691588785046728,
#    'total_return': 0.1653399999999916,
#    'annual_return': 0.3708560747663363,
#    'daily_return': 0.001543957606546477,
#    'return_std': 0.06288766039682228,
#    'sharpe_ratio': 0.3803431108533925,
#    'return_drawdown_ratio': 0.4502968571272659}),
#  ("{'boll_window': 510, 'boll_dev': 1}",
#   -0.005064420393940785,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 52,
#    'loss_days': 55,
#    'capital': 1000000,
#    'end_balance': 1003256.36,
#    'max_drawdown': -21621.399999999907,
#    'max_ddpercent': -2.1108970454275373,
#    'max_drawdown_duration': 90,
#    'total_net_pnl': 3256.3599999999888,
#    'daily_net_pnl': 30.43327102803728,
#    'total_commission': 79843.64,
#    'daily_commission': 746.2022429906542,
#    'total_slippage': 40900.0,
#    'daily_slippage': 382.2429906542056,
#    'total_turnover': 399218200.0,
#    'daily_turnover': 3731011.214953271,
#    'total_trade_count': 409,
#    'daily_trade_count': 3.822429906542056,
#    'total_return': 0.3256359999999958,
#    'annual_return': 0.7303985046728878,
#    'daily_return': -7.083207283048032e-05,
#    'return_std': 0.2166735121578919,
#    'sharpe_ratio': -0.005064420393940785,
#    'return_drawdown_ratio': 0.1542642739044822}),
#  ("{'boll_window': 410, 'boll_dev': 1}",
#   -0.28639701377121746,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 56,
#    'loss_days': 47,
#    'capital': 1000000,
#    'end_balance': 998580.28,
#    'max_drawdown': -37782.83999999997,
#    'max_ddpercent': -3.685600868152259,
#    'max_drawdown_duration': 104,
#    'total_net_pnl': -1419.7200000000057,
#    'daily_net_pnl': -13.268411214953325,
#    'total_commission': 105419.72000000002,
#    'daily_commission': 985.2310280373833,
#    'total_slippage': 53400.0,
#    'daily_slippage': 499.06542056074767,
#    'total_turnover': 527098600.0,
#    'daily_turnover': 4926155.140186916,
#    'total_trade_count': 534,
#    'daily_trade_count': 4.990654205607477,
#    'total_return': -0.14197200000000132,
#    'annual_return': -0.31844186915888145,
#    'daily_return': -0.005820295940285233,
#    'return_std': 0.3148344174388704,
#    'sharpe_ratio': -0.28639701377121746,
#    'return_drawdown_ratio': -0.038520720251289074}),
#  ("{'boll_window': 110, 'boll_dev': 3}",
#   -0.5734218754609757,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 42,
#    'loss_days': 33,
#    'capital': 1000000,
#    'end_balance': 994300.0,
#    'max_drawdown': -15421.079999999958,
#    'max_ddpercent': -1.5272613700409186,
#    'max_drawdown_duration': 79,
#    'total_net_pnl': -5700.000000000003,
#    'daily_net_pnl': -53.2710280373832,
#    'total_commission': 32300.0,
#    'daily_commission': 301.86915887850466,
#    'total_slippage': 18200.0,
#    'daily_slippage': 170.09345794392524,
#    'total_turnover': 161500000.0,
#    'daily_turnover': 1509345.7943925234,
#    'total_trade_count': 182,
#    'daily_trade_count': 1.7009345794392523,
#    'total_return': -0.5700000000000038,
#    'annual_return': -1.278504672897205,
#    'daily_return': -0.005342342987017211,
#    'return_std': 0.144332166622086,
#    'sharpe_ratio': -0.5734218754609757,
#    'return_drawdown_ratio': -0.37321706106187463}),
#  ("{'boll_window': 110, 'boll_dev': 5}",
#   -0.5954906669138726,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 3,
#    'loss_days': 1,
#    'capital': 1000000,
#    'end_balance': 998220.32,
#    'max_drawdown': -4100.920000000042,
#    'max_ddpercent': -0.40985651284198565,
#    'max_drawdown_duration': 42,
#    'total_net_pnl': -1779.68,
#    'daily_net_pnl': -16.632523364485984,
#    'total_commission': 1179.68,
#    'daily_commission': 11.025046728971963,
#    'total_slippage': 600.0,
#    'daily_slippage': 5.607476635514018,
#    'total_turnover': 5898400.0,
#    'daily_turnover': 55125.233644859814,
#    'total_trade_count': 6,
#    'daily_trade_count': 0.056074766355140186,
#    'total_return': -0.17796800000000612,
#    'annual_return': -0.3991805607476773,
#    'daily_return': -0.0016647341232398226,
#    'return_std': 0.04330873945403786,
#    'sharpe_ratio': -0.5954906669138726,
#    'return_drawdown_ratio': -0.43422025617199145}),
#  ("{'boll_window': 310, 'boll_dev': 1}",
#   -0.6237588966427595,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 46,
#    'loss_days': 61,
#    'capital': 1000000,
#    'end_balance': 992556.72,
#    'max_drawdown': -41301.47999999998,
#    'max_ddpercent': -3.997972626194435,
#    'max_drawdown_duration': 120,
#    'total_net_pnl': -7443.280000000012,
#    'daily_net_pnl': -69.56336448598141,
#    'total_commission': 120543.28000000001,
#    'daily_commission': 1126.572710280374,
#    'total_slippage': 61500.0,
#    'daily_slippage': 574.7663551401869,
#    'total_turnover': 602716400.0,
#    'daily_turnover': 5632863.551401869,
#    'total_trade_count': 615,
#    'daily_trade_count': 5.747663551401869,
#    'total_return': -0.7443280000000052,
#    'annual_return': -1.6695207476635632,
#    'daily_return': -0.008685623999829943,
#    'return_std': 0.2157197422518001,
#    'sharpe_ratio': -0.6237588966427595,
#    'return_drawdown_ratio': -0.1861763622700217}),
#  ("{'boll_window': 510, 'boll_dev': 5}",
#   -0.8226916405022521,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 2,
#    'loss_days': 4,
#    'capital': 1000000,
#    'end_balance': 998000.8,
#    'max_drawdown': -3911.0400000000373,
#    'max_ddpercent': -0.3911040000000037,
#    'max_drawdown_duration': 83,
#    'total_net_pnl': -1999.2000000000003,
#    'daily_net_pnl': -18.684112149532712,
#    'total_commission': 799.2,
#    'daily_commission': 7.469158878504674,
#    'total_slippage': 400.0,
#    'daily_slippage': 3.7383177570093458,
#    'total_turnover': 3996000.0,
#    'daily_turnover': 37345.79439252336,
#    'total_trade_count': 4,
#    'daily_trade_count': 0.037383177570093455,
#    'total_return': -0.19991999999999788,
#    'annual_return': -0.4484186915887803,
#    'daily_return': -0.0018702813717644774,
#    'return_std': 0.03521887545201551,
#    'sharpe_ratio': -0.8226916405022521,
#    'return_drawdown_ratio': -0.5111683848797148}),
#  ("{'boll_window': 210, 'boll_dev': 2}",
#   -0.9805419443676325,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 54,
#    'loss_days': 53,
#    'capital': 1000000,
#    'end_balance': 986852.28,
#    'max_drawdown': -33131.76000000001,
#    'max_ddpercent': -3.2552778879079014,
#    'max_drawdown_duration': 107,
#    'total_net_pnl': -13147.720000000001,
#    'daily_net_pnl': -122.8758878504673,
#    'total_commission': 70847.72000000002,
#    'daily_commission': 662.1282242990656,
#    'total_slippage': 37100.0,
#    'daily_slippage': 346.7289719626168,
#    'total_turnover': 354238600.0,
#    'daily_turnover': 3310641.121495327,
#    'total_trade_count': 371,
#    'daily_trade_count': 3.467289719626168,
#    'total_return': -1.3147719999999974,
#    'annual_return': -2.949021308411209,
#    'daily_return': -0.011983318904061804,
#    'return_std': 0.18932874749240927,
#    'sharpe_ratio': -0.9805419443676325,
#    'return_drawdown_ratio': -0.4038893284299528}),
#  ("{'boll_window': 110, 'boll_dev': 2}",
#   -1.423415069428368,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 52,
#    'loss_days': 55,
#    'capital': 1000000,
#    'end_balance': 981915.12,
#    'max_drawdown': -40777.0,
#    'max_ddpercent': -3.9874112916619304,
#    'max_drawdown_duration': 121,
#    'total_net_pnl': -18084.880000000005,
#    'daily_net_pnl': -169.01757009345798,
#    'total_commission': 118884.88000000002,
#    'daily_commission': 1111.0736448598132,
#    'total_slippage': 63200.0,
#    'daily_slippage': 590.6542056074767,
#    'total_turnover': 594424400.0,
#    'daily_turnover': 5555368.224299066,
#    'total_trade_count': 632,
#    'daily_trade_count': 5.906542056074766,
#    'total_return': -1.808487999999997,
#    'annual_return': -4.056421682242984,
#    'daily_return': -0.0174076444845962,
#    'return_std': 0.18945848932909107,
#    'sharpe_ratio': -1.423415069428368,
#    'return_drawdown_ratio': -0.4535494002792547}),
#  ("{'boll_window': 210, 'boll_dev': 1}",
#   -1.746142699838038,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 46,
#    'loss_days': 59,
#    'capital': 1000000,
#    'end_balance': 962126.56,
#    'max_drawdown': -66261.31999999995,
#    'max_ddpercent': -6.470270431996093,
#    'max_drawdown_duration': 120,
#    'total_net_pnl': -37873.44000000002,
#    'daily_net_pnl': -353.95738317757025,
#    'total_commission': 161473.44000000003,
#    'daily_commission': 1509.0975700934582,
#    'total_slippage': 82800.0,
#    'daily_slippage': 773.8317757009346,
#    'total_turnover': 807367200.0,
#    'daily_turnover': 7545487.85046729,
#    'total_trade_count': 828,
#    'daily_trade_count': 7.738317757009346,
#    'total_return': -3.7873439999999925,
#    'annual_return': -8.494977196261665,
#    'daily_return': -0.03748854854350739,
#    'return_std': 0.3326017379815742,
#    'sharpe_ratio': -1.746142699838038,
#    'return_drawdown_ratio': -0.585345549278933}),
#  ("{'boll_window': 10, 'boll_dev': 5}",
#   -1.9056253884788086,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 0,
#    'loss_days': 5,
#    'capital': 1000000,
#    'end_balance': 991591.24,
#    'max_drawdown': -8408.76000000001,
#    'max_ddpercent': -0.840876000000001,
#    'max_drawdown_duration': 132,
#    'total_net_pnl': -8408.76,
#    'daily_net_pnl': -78.58654205607476,
#    'total_commission': 5608.759999999999,
#    'daily_commission': 52.41831775700934,
#    'total_slippage': 3400.0,
#    'daily_slippage': 31.77570093457944,
#    'total_turnover': 28043800.0,
#    'daily_turnover': 262091.58878504674,
#    'total_trade_count': 34,
#    'daily_trade_count': 0.3177570093457944,
#    'total_return': -0.8408760000000015,
#    'annual_return': -1.8860770093457977,
#    'daily_return': -0.007891881371462694,
#    'return_std': 0.06415767822303961,
#    'sharpe_ratio': -1.9056253884788086,
#    'return_drawdown_ratio': -1.0000000000000007}),
#  ("{'boll_window': 10, 'boll_dev': 4}",
#   -1.9056253884788086,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 0,
#    'loss_days': 5,
#    'capital': 1000000,
#    'end_balance': 991591.24,
#    'max_drawdown': -8408.76000000001,
#    'max_ddpercent': -0.840876000000001,
#    'max_drawdown_duration': 132,
#    'total_net_pnl': -8408.76,
#    'daily_net_pnl': -78.58654205607476,
#    'total_commission': 5608.759999999999,
#    'daily_commission': 52.41831775700934,
#    'total_slippage': 3400.0,
#    'daily_slippage': 31.77570093457944,
#    'total_turnover': 28043800.0,
#    'daily_turnover': 262091.58878504674,
#    'total_trade_count': 34,
#    'daily_trade_count': 0.3177570093457944,
#    'total_return': -0.8408760000000015,
#    'annual_return': -1.8860770093457977,
#    'daily_return': -0.007891881371462694,
#    'return_std': 0.06415767822303961,
#    'sharpe_ratio': -1.9056253884788086,
#    'return_drawdown_ratio': -1.0000000000000007}),
#  ("{'boll_window': 10, 'boll_dev': 3}",
#   -1.9576172063706736,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 0,
#    'loss_days': 6,
#    'capital': 1000000,
#    'end_balance': 991359.16,
#    'max_drawdown': -8640.839999999967,
#    'max_ddpercent': -0.8640839999999967,
#    'max_drawdown_duration': 132,
#    'total_net_pnl': -8640.84,
#    'daily_net_pnl': -80.75551401869158,
#    'total_commission': 6040.839999999999,
#    'daily_commission': 56.456448598130834,
#    'total_slippage': 3600.0,
#    'daily_slippage': 33.64485981308411,
#    'total_turnover': 30204200.0,
#    'daily_turnover': 282282.2429906542,
#    'total_trade_count': 36,
#    'daily_trade_count': 0.3364485981308411,
#    'total_return': -0.8640839999999983,
#    'annual_return': -1.9381323364485943,
#    'daily_return': -0.00811064347186814,
#    'return_std': 0.0641849427791008,
#    'sharpe_ratio': -1.9576172063706736,
#    'return_drawdown_ratio': -1.0000000000000018}),
#  ("{'boll_window': 110, 'boll_dev': 1}",
#   -5.611265259249166,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 33,
#    'loss_days': 74,
#    'capital': 1000000,
#    'end_balance': 912209.96,
#    'max_drawdown': -113355.40000000002,
#    'max_ddpercent': -11.052966921581675,
#    'max_drawdown_duration': 132,
#    'total_net_pnl': -87790.04,
#    'daily_net_pnl': -820.4676635514018,
#    'total_commission': 252390.04000000004,
#    'daily_commission': 2358.785420560748,
#    'total_slippage': 130000.0,
#    'daily_slippage': 1214.9532710280373,
#    'total_turnover': 1261950200.0,
#    'daily_turnover': 11793927.102803739,
#    'total_trade_count': 1300,
#    'daily_trade_count': 12.149532710280374,
#    'total_return': -8.779004,
#    'annual_return': -19.691223925233643,
#    'daily_return': -0.0869827215291253,
#    'return_std': 0.24014735809169524,
#    'sharpe_ratio': -5.611265259249166,
#    'return_drawdown_ratio': -0.7942667396261174}),
#  ("{'boll_window': 10, 'boll_dev': 2}",
#   -15.138867299348181,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 12,
#    'loss_days': 94,
#    'capital': 1000000,
#    'end_balance': 808592.9199999999,
#    'max_drawdown': -194410.88000000012,
#    'max_ddpercent': -19.38286574786657,
#    'max_drawdown_duration': 132,
#    'total_net_pnl': -191407.08000000002,
#    'daily_net_pnl': -1788.8512149532712,
#    'total_commission': 271207.08,
#    'daily_commission': 2534.6456074766356,
#    'total_slippage': 149200.0,
#    'daily_slippage': 1394.392523364486,
#    'total_turnover': 1356035400.0,
#    'daily_turnover': 12673228.037383178,
#    'total_trade_count': 1492,
#    'daily_trade_count': 13.94392523364486,
#    'total_return': -19.140708000000007,
#    'annual_return': -42.93242915887852,
#    'daily_return': -0.19773900142815035,
#    'return_std': 0.2023506367507125,
#    'sharpe_ratio': -15.138867299348181,
#    'return_drawdown_ratio': -0.9875066075875174}),
#  ("{'boll_window': 10, 'boll_dev': 1}",
#   -23.748758033431706,
#   {'start_date': datetime.date(2023, 1, 17),
#    'end_date': datetime.date(2023, 6, 29),
#    'total_days': 107,
#    'profit_days': 6,
#    'loss_days': 101,
#    'capital': 1000000,
#    'end_balance': 263637.35999999987,
#    'max_drawdown': -731669.4000000001,
#    'max_ddpercent': -73.51194922055991,
#    'max_drawdown_duration': 163,
#    'total_net_pnl': -736362.6400000001,
#    'daily_net_pnl': -6881.893831775702,
#    'total_commission': 958062.6400000001,
#    'daily_commission': 8953.856448598131,
#    'total_slippage': 513700.0,
#    'daily_slippage': 4800.934579439252,
#    'total_turnover': 4790313200.0,
#    'daily_turnover': 44769282.24299066,
#    'total_trade_count': 5137,
#    'daily_trade_count': 48.00934579439252,
#    'total_return': -73.63626400000001,
#    'annual_return': -165.16545196261683,
#    'daily_return': -1.2415667931510177,
#    'return_std': 0.8099063549022484,
#    'sharpe_ratio': -23.748758033431706,
#    'return_drawdown_ratio': -1.0016910826166112})]

# %%
engine.run_bf_optimization(setting)
# Out:
# 2024-01-08 09:54:48.474500	开始执行穷举算法优化
# 2024-01-08 09:54:48.474500	参数优化空间：50
# 100%|██████████| 50/50 [01:03<00:00,  1.26s/it]
# 2024-01-08 09:55:51.571813	穷举算法优化完成，耗时63秒

# %% [markdown]
# # StatArb1Dev

# %%
spread = SpreadData(
    name="FG-Spread",
    legs=[LegData("FG307.CZCE"), LegData("FG308.CZCE")],
    variable_symbols={"A": "FG307.CZCE", "B": "FG308.CZCE"},
    variable_directions={"A": 1, "B": -1},
    price_formula="A-B",
    trading_multipliers={"FG307.CZCE": 1, "FG308.CZCE": 1},
    active_symbol="FG307.CZCE",
    min_volume=1,
    compile_formula=False                          # 回测时不编译公式，compile_formula传False，从而支持多进程优化
)

engine = BacktestingEngine()
engine.set_parameters(
    spread=spread,
    interval="1m",
    start=datetime(2023, 1, 1), # max at 4,1
    end=datetime(2023, 6, 30),
    rate=0.0006,
    # rate = 0,
    # slippage=0.5,
    slippage=0.5,
    size=20,
    pricetick=1,
    capital=1_000_000,
)
engine.add_strategy(StatArb1Dev, {"boll_window":600, "boll_dev":3})

engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# this utility.py is being used
# 2023-12-16 23:27:14.645997	开始加载历史数据
# 2023-12-16 23:27:18.711023	历史数据加载完成，数据量：39885
# 2023-12-16 23:27:18.771314	策略初始化完成
# 2023-12-16 23:27:18.771314	开始回放历史数据
# 2023-12-16 23:27:19.660308	历史数据回放结束
# 2023-12-16 23:27:19.660308	开始计算逐日盯市盈亏
# 2023-12-16 23:27:19.662319	逐日盯市盈亏计算完成
# 2023-12-16 23:27:19.662319	开始计算策略统计指标
# 2023-12-16 23:27:19.666318	------------------------------
# 2023-12-16 23:27:19.666318	首个交易日：	2023-01-17
# 2023-12-16 23:27:19.666318	最后交易日：	2023-06-29
# 2023-12-16 23:27:19.666318	总交易日：	107
# 2023-12-16 23:27:19.666318	盈利交易日：	21
# 2023-12-16 23:27:19.666318	亏损交易日：	48
# 2023-12-16 23:27:19.666318	起始资金：	1,000,000.00
# 2023-12-16 23:27:19.666318	结束资金：	871,180.88
# 2023-12-16 23:27:19.666318	总收益率：	-12.88%
# 2023-12-16 23:27:19.666318	年化收益：	-28.89%
# 2023-12-16 23:27:19.666318	最大回撤: 	-128,801.20
# 2023-12-16 23:27:19.666318	百分比最大回撤: -12.88%
# 2023-12-16 23:27:19.666318	最长回撤天数: 	162
# 2023-12-16 23:27:19.666318	总盈亏：	-128,819.12
# 2023-12-16 23:27:19.666318	总手续费：	141,219.12
# 2023-12-16 23:27:19.666318	总滑点：	35,400.00
# 2023-12-16 23:27:19.666318	总成交金额：	235,365,200.00
# 2023-12-16 23:27:19.666318	总成交笔数：	354
# 2023-12-16 23:27:19.666318	日均盈亏：	-1,203.92
# 2023-12-16 23:27:19.666318	日均手续费：	1,319.80
# 2023-12-16 23:27:19.666318	日均滑点：	330.84
# 2023-12-16 23:27:19.666318	日均成交金额：	2,199,674.77
# 2023-12-16 23:27:19.666318	日均成交笔数：	3.308411214953271
# 2023-12-16 23:27:19.666318	日均收益率：	-0.13%
# 2023-12-16 23:27:19.666318	收益标准差：	0.32%
# 2023-12-16 23:27:19.666318	Sharpe Ratio：	-6.20
# 2023-12-16 23:27:19.666318	收益回撤比：	-1.00
